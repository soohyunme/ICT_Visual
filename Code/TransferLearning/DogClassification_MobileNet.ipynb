# %%
# !nvidia-smi
# Out:
# Sat Apr  2 14:03:15 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   68C    P0    71W / 149W |   8469MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
# !rm -r Dog_breed
# !rm -r dog_dataset

# %%
ROOT_DIR = '/content'
DRIVE_DIR = '/content/drive/MyDrive/Git/ICT_Visual/Data'

# %%
import zipfile
import os

with zipfile.ZipFile('/content/drive/MyDrive/Git/ICT_Visual/Data/dog_dataset_rename.zip') as target_file:
    target_file.extractall(os.path.join(ROOT_DIR,'dog_dataset'))

# %% [markdown]
# # Train data dir로 복사

# %%
import os
os.mkdir(os.path.join(ROOT_DIR,'Dog_breed'))
os.mkdir(os.path.join(ROOT_DIR,'Dog_breed/test'))

# %%
label_list = os.listdir(os.path.join(ROOT_DIR,'dog_dataset'))
for label in label_list:
    os.mkdir(os.path.join(ROOT_DIR,'Dog_breed/test',label))

# %%
TRAIN_DATA_ROOT_DIR = os.path.join(ROOT_DIR,'Dog_breed/train')
TEST_DATA_ROOT_DIR = os.path.join(ROOT_DIR,'Dog_breed/test')

# %%
#================================================
# 정답 및 전체 데이터 개수
#================================================

DATA_DIR = os.path.join(ROOT_DIR,'dog_dataset')

for label_name in label_list:

    print(f'label {label_name} => {len(os.listdir(os.path.join(DATA_DIR, label_name)))}')

print('================================================================')
# Out:
# label Yorkshire_terrier => 164
# label Shepherd => 152
# label Jindo_dog => 205
# label Chihuahua => 152
# ================================================================

# %%
import shutil

if not os.path.exists(os.path.join(ROOT_DIR,'Dog_breed/train')):
    src_dir = os.path.join(ROOT_DIR,'dog_dataset')
    dst_dir = os.path.join(ROOT_DIR,'Dog_breed/train')
    shutil.copytree(src_dir, dst_dir)
    print(src_dir, 'is copy !', dst_dir)
# Out:
# /content/dog_dataset is copy ! /content/Dog_breed/train

# %%
#================================================
# train 데이터 정답 및 전체 데이터 개수
#================================================

label_list = os.listdir(TRAIN_DATA_ROOT_DIR)

for label_name in label_list:

    print(f'label {label_name} => {len(os.listdir(os.path.join(TRAIN_DATA_ROOT_DIR, label_name)))}')

print('================================================================')
# Out:
# label Yorkshire_terrier => 164
# label Shepherd => 152
# label Jindo_dog => 205
# label Chihuahua => 152
# ================================================================

# %% [markdown]
# # Train Test Split

# %%
import random

split_ratio = 0.1

label_list = os.listdir(TRAIN_DATA_ROOT_DIR)
print(label_list)

for label_name in label_list:

    train_path = os.path.join(TRAIN_DATA_ROOT_DIR,label_name) 
    test_path = os.path.join(TEST_DATA_ROOT_DIR,label_name)
    file_name_list = os.listdir(train_path)

    random.shuffle(file_name_list)
    split_num = int(len(file_name_list)*split_ratio)

    test_file_name_list = file_name_list[0:split_num]
    move_nums = 0

    for file_name in test_file_name_list:
        try:
            shutil.move(os.path.join(train_path,file_name),
                        os.path.join(test_path,file_name))
            move_nums+=1
        except Exception as err:
            print(str(err))
    print(move_nums, 'is moved into ',label_name, '(TRAIN -> TEST)')
# Out:
# ['Yorkshire_terrier', 'Shepherd', 'Jindo_dog', 'Chihuahua']
# 16 is moved into  Yorkshire_terrier (TRAIN -> TEST)
# 15 is moved into  Shepherd (TRAIN -> TEST)
# 20 is moved into  Jindo_dog (TRAIN -> TEST)
# 15 is moved into  Chihuahua (TRAIN -> TEST)

# %% [markdown]
# # train test 비율 확인

# %%
# TRAIN 
train_label_list = os.listdir(TRAIN_DATA_ROOT_DIR)
for label_name in train_label_list:

    print(f'train {label_name} => {len(os.listdir(os.path.join(TRAIN_DATA_ROOT_DIR, label_name)))}')
print('=============================================')

# TEST
test_label_list = os.listdir(TEST_DATA_ROOT_DIR)
for label_name in test_label_list:

    print(f'test {label_name} => {len(os.listdir(os.path.join(TEST_DATA_ROOT_DIR, label_name)))}')
print('=============================================')
# Out:
# train Yorkshire_terrier => 148
# train Shepherd => 137
# train Jindo_dog => 185
# train Chihuahua => 137
# =============================================
# test Yorkshire_terrier => 16
# test Shepherd => 15
# test Jindo_dog => 20
# test Chihuahua => 15
# =============================================

# %% [markdown]
# # 이미지 사이즈 정의

# %%
IMG_WIDTH = 224
IMG_HEIGHT = 224

# %% [markdown]
# # ImageDataGenerator 정의

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_gen = ImageDataGenerator(rescale=1./255, validation_split=0.1)
test_gen = ImageDataGenerator(rescale=1./255)

# %%
train_data = train_gen.flow_from_directory(directory=TRAIN_DATA_ROOT_DIR,
                                           batch_size=16, color_mode='rgb',
                                           class_mode='sparse',
                                           subset = 'training',
                                           target_size=(IMG_WIDTH, IMG_HEIGHT))
validation_data = train_gen.flow_from_directory(directory=TRAIN_DATA_ROOT_DIR,
                                          batch_size=16, color_mode='rgb',
                                          class_mode='sparse',
                                          subset = 'validation',
                                          target_size=(IMG_WIDTH, IMG_HEIGHT))                                                                                      
test_data = test_gen.flow_from_directory(directory=TEST_DATA_ROOT_DIR,
                                          batch_size=16, color_mode='rgb',
                                          class_mode='sparse',
                                          target_size=(IMG_WIDTH, IMG_HEIGHT))
# Out:
# Found 549 images belonging to 4 classes.
# Found 58 images belonging to 4 classes.
# Found 66 images belonging to 4 classes.

# %%
print(train_data.class_indices)
print(train_data.num_classes)
# Out:
# {'Chihuahua': 0, 'Jindo_dog': 1, 'Shepherd': 2, 'Yorkshire_terrier': 3}
# 4

# %% [markdown]
# # 모델링

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNet

# %%
pre_trained_model = MobileNet(weights='imagenet', include_top=False, input_shape=(IMG_WIDTH,IMG_HEIGHT,3))

# %%
class_nums = train_data.num_classes
model = Sequential()

model.add(pre_trained_model)

model.add(GlobalAveragePooling2D())

model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(class_nums,activation='softmax'))

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenet_1.00_224 (Functio  (None, 7, 7, 1024)       3228864
#  nal)
#
#  global_average_pooling2d_5   (None, 1024)             0
#  (GlobalAveragePooling2D)
#
#  dense_11 (Dense)            (None, 64)                65600
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_12 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 3,294,724
# Trainable params: 3,272,836
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(3e-5),
              loss='sparse_categorical_crossentropy',
              metrics=['acc'])

# %%
from datetime import datetime
from tensorflow.keras.callbacks import EarlyStopping

earlystop = EarlyStopping(monitor='val_acc',
                          patience=5,
                          verbose=1)

start_time = datetime.now()

hist = model.fit(train_data,
                 epochs=30,
                 validation_data=validation_data,
                 callbacks=[earlystop])

end_time = datetime.now()

print('\n\nElapsed time => ', end_time - start_time)
# Out:
# Epoch 1/30
# 35/35 [==============================] - 11s 235ms/step - loss: 1.7316 - acc: 0.3242 - val_loss: 1.2415 - val_acc: 0.5000
# Epoch 2/30
# 35/35 [==============================] - 8s 217ms/step - loss: 0.8803 - acc: 0.6157 - val_loss: 0.9480 - val_acc: 0.6034
# Epoch 3/30
# 35/35 [==============================] - 8s 217ms/step - loss: 0.6680 - acc: 0.7596 - val_loss: 0.7017 - val_acc: 0.6724
# Epoch 4/30
# 35/35 [==============================] - 8s 214ms/step - loss: 0.5283 - acc: 0.7978 - val_loss: 0.5754 - val_acc: 0.7931
# Epoch 5/30
# 35/35 [==============================] - 8s 217ms/step - loss: 0.3770 - acc: 0.8834 - val_loss: 0.4879 - val_acc: 0.8276
# Epoch 6/30
# 35/35 [==============================] - 8s 220ms/step - loss: 0.3316 - acc: 0.8925 - val_loss: 0.4179 - val_acc: 0.8276
# Epoch 7/30
# 35/35 [==============================] - 8s 214ms/step - loss: 0.2758 - acc: 0.9126 - val_loss: 0.3871 - val_acc: 0.8448
# Epoch 8/30
# 35/35 [==============================] - 8s 215ms/step - loss: 0.2210 - acc: 0.9271 - val_loss: 0.3495 - val_acc: 0.8621
# Epoch 9/30
# 35/35 [==============================] - 8s 215ms/step - loss: 0.1993 - acc: 0.9490 - val_loss: 0.3251 - val_acc: 0.8621
# Epoch 10/30
# 35/35 [==============================] - 8s 215ms/step - loss: 0.1729 - acc: 0.9672 - val_loss: 0.3061 - val_acc: 0.8621
# Epoch 11/30
# 35/35 [==============================] - 8s 210ms/step - loss: 0.1402 - acc: 0.9727 - val_loss: 0.2884 - val_acc: 0.8621
# Epoch 12/30
# 35/35 [==============================] - 8s 216ms/step - loss: 0.1089 - acc: 0.9836 - val_loss: 0.2630 - val_acc: 0.8621
# Epoch 13/30
# 35/35 [==============================] - 8s 219ms/step - loss: 0.1496 - acc: 0.9526 - val_loss: 0.2655 - val_acc: 0.8793
# Epoch 14/30
# 35/35 [==============================] - 8s 209ms/step - loss: 0.1140 - acc: 0.9781 - val_loss: 0.2501 - val_acc: 0.8966
# Epoch 15/30
# 35/35 [==============================] - 8s 224ms/step - loss: 0.1184 - acc: 0.9690 - val_loss: 0.2268 - val_acc: 0.8966
# Epoch 16/30
# 35/35 [==============================] - 8s 217ms/step - loss: 0.0960 - acc: 0.9763 - val_loss: 0.2187 - val_acc: 0.8966
# Epoch 17/30
# 35/35 [==============================] - 8s 219ms/step - loss: 0.0743 - acc: 0.9891 - val_loss: 0.2033 - val_acc: 0.8966
# Epoch 18/30
# 35/35 [==============================] - 8s 211ms/step - loss: 0.0636 - acc: 0.9891 - val_loss: 0.1927 - val_acc: 0.9138
# Epoch 19/30
# 35/35 [==============================] - 7s 213ms/step - loss: 0.0561 - acc: 0.9891 - val_loss: 0.1862 - val_acc: 0.8966
# Epoch 20/30
# 35/35 [==============================] - 8s 218ms/step - loss: 0.0489 - acc: 0.9945 - val_loss: 0.1863 - val_acc: 0.9138
# Epoch 21/30
# 35/35 [==============================] - 8s 221ms/step - loss: 0.0612 - acc: 0.9909 - val_loss: 0.1865 - val_acc: 0.9138
# Epoch 22/30
# 35/35 [==============================] - 8s 224ms/step - loss: 0.0564 - acc: 0.9872 - val_loss: 0.1847 - val_acc: 0.9310
# Epoch 23/30
# 35/35 [==============================] - 8s 220ms/step - loss: 0.0429 - acc: 0.9982 - val_loss: 0.1848 - val_acc: 0.9310
# Epoch 24/30
# 35/35 [==============================] - 8s 216ms/step - loss: 0.0465 - acc: 0.9854 - val_loss: 0.1853 - val_acc: 0.9310
# Epoch 25/30
# 35/35 [==============================] - 8s 218ms/step - loss: 0.0347 - acc: 0.9982 - val_loss: 0.1716 - val_acc: 0.9310
# Epoch 26/30
# 35/35 [==============================] - 8s 223ms/step - loss: 0.0434 - acc: 0.9909 - val_loss: 0.1602 - val_acc: 0.9310
# Epoch 27/30
# 35/35 [==============================] - 8s 222ms/step - loss: 0.0383 - acc: 0.9927 - val_loss: 0.1513 - val_acc: 0.9483
# Epoch 28/30
# 35/35 [==============================] - 8s 204ms/step - loss: 0.0376 - acc: 0.9909 - val_loss: 0.1464 - val_acc: 0.9483
# Epoch 29/30
# 35/35 [==============================] - 8s 218ms/step - loss: 0.0287 - acc: 0.9964 - val_loss: 0.1437 - val_acc: 0.9310
# Epoch 30/30
# 35/35 [==============================] - 8s 219ms/step - loss: 0.0241 - acc: 0.9982 - val_loss: 0.1432 - val_acc: 0.9310
#
#
# Elapsed time =>  0:03:57.310469

# %%
model.evaluate(test_data)
# Out:
# 5/5 [==============================] - 1s 129ms/step - loss: 0.0734 - acc: 0.9545
# [0.0733616054058075, 0.9545454382896423]

# %%
import matplotlib.pyplot as plt

plt.plot(hist.history['acc'], label='train')
plt.plot(hist.history['val_acc'], label='validation')
plt.title('Accuracy Trend')
plt.xlabel('epochs')
plt.ylabel('acc')
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(hist.history['loss'], label='train')
plt.plot(hist.history['val_loss'], label='validation')
plt.title('Loss Trend')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.grid()
plt.legend()
plt.show()
