# %%
# !wget https://sid.erda.dk/public/archives/daaeac0d7ce1152aea9b61d9f1e19370/GTSRB_Final_Training_Images.zip
# Out:
# --2022-03-19 13:40:46--  https://sid.erda.dk/public/archives/daaeac0d7ce1152aea9b61d9f1e19370/GTSRB_Final_Training_Images.zip
# Resolving sid.erda.dk (sid.erda.dk)... 130.225.104.13
# Connecting to sid.erda.dk (sid.erda.dk)|130.225.104.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 276294756 (263M) [application/zip]
# Saving to: ‘GTSRB_Final_Training_Images.zip’
#
# GTSRB_Final_Trainin 100%[===================>] 263.50M  24.6MB/s    in 12s
#
# 2022-03-19 13:40:59 (21.9 MB/s) - ‘GTSRB_Final_Training_Images.zip’ saved [276294756/276294756]

# %%
import zipfile

with zipfile.ZipFile('/content/GTSRB_Final_Training_Images.zip','r') as target_file:

    target_file.extractall('/content/GTSRB_Final_Training_Images/')

# %%
import os
from glob import glob

label_name_list = os.listdir('/content/GTSRB_Final_Training_Images/GTSRB/Final_Training/Images/')

print('total label nums = ', len(label_name_list))
print('='*50)
print(label_name_list)
# Out:
# total label nums =  43
# ==================================================
# ['00001', '00036', '00026', '00023', '00016', '00042', '00015', '00022', '00025', '00004', '00024', '00019', '00006', '00034', '00028', '00033', '00010', '00000', '00013', '00032', '00018', '00003', '00017', '00041', '00008', '00039', '00035', '00011', '00038', '00031', '00007', '00037', '00002', '00020', '00014', '00012', '00009', '00029', '00005', '00021', '00030', '00040', '00027']

# %% [markdown]
# # 작업폴더 /content/GTSRB 생성

# %%
import os

if not os.path.exists('/content/GTSRB'):
    os.mkdir('/content/GTSRB')
    print('GTSRB dir is created !')
# Out:
# GTSRB dir is created !

# %% [markdown]
# # Shutil copy를 이용해 train 폴더에 복사본 생성

# %%
import shutil

src_root_dir = '/content/GTSRB_Final_Training_Images/GTSRB/Final_Training/Images'
dst_root_dir = '/content/GTSRB/train'

if os.path.exists(dst_root_dir):
    os.rmdir(dst_root_dir)
    print(dst_root_dir + 'is deleted !')

shutil.copytree(src_root_dir, dst_root_dir)
# Out:
# '/content/GTSRB/train'

# %% [markdown]
# # /content/GTSRB/test 폴더 생성 후 train 디렉토리와 동일한 이름의 디렉토리를 test 하위 디렉토리로 만든다

# %%
import os

label_name_list = os.listdir('/content/GTSRB/train/')


if not os.path.exists('/content/GTSRB/test/'):
    os.mkdir('/content/GTSRB/test/')
    print('/content/GTSRB/test dir is created !')
    
    count = 0

    for label_name in label_name_list:
        os.mkdir('/content/GTSRB/test/' + label_name)
        count += 1

    print('train label count => ', count)
# Out:
# /content/GTSRB/test dir is created !
# train label count =>  43

# %% [markdown]
# # train 데이터에서 test 데이터를 분리하여 이동처리

# %%
import os
import shutil
import random
from glob import glob

ratio = 0.2

train_root_dir = '/content/GTSRB/train/'
test_root_dir = '/content/GTSRB/test/'

image_label_list = os.listdir(train_root_dir)

for label_name in image_label_list:
    
    train_image_list = glob(train_root_dir + label_name+'/*.ppm')

    print('========================================================================')
    print('total [%s] image file nums => [%s]'%(label_name, len(train_image_list)))
    
    split_num = int(ratio * len(train_image_list))

    print('split nums => ', split_num)

    test_image_list = train_image_list[0:split_num] 

    move_nums = 0

    for image_file in test_image_list:

        shutil.move(image_file, test_root_dir + label_name)
        
        move_nums += 1

    print('total move nums => ', move_nums)
    print('========================================================================')
# Out:
# ========================================================================
# total [00001] image file nums => [2220]
# split nums =>  444
# total move nums =>  444
# ========================================================================
# ========================================================================
# total [00036] image file nums => [390]
# split nums =>  78
# total move nums =>  78
# ========================================================================
# ========================================================================
# total [00026] image file nums => [600]
# split nums =>  120
# total move nums =>  120
# ========================================================================
# ========================================================================
# total [00023] image file nums => [510]
# split nums =>  102
# total move nums =>  102
# ========================================================================
# ========================================================================
# total [00016] image file nums => [420]
# split nums =>  84
# total move nums =>  84
# ========================================================================
# ========================================================================
# total [00042] image file nums => [240]
# split nums =>  48
# total move nums =>  48
# ========================================================================
# ========================================================================
# total [00015] image file nums => [630]
# split nums =>  126
# total move nums =>  126
# ========================================================================
# ========================================================================
# total [00022] image file nums => [390]
# split nums =>  78
# total move nums =>  78
# ========================================================================
# ========================================================================
# total [00025] image file nums => [1500]
# split nums =>  300
# total move nums =>  300
# ========================================================================
# ========================================================================
# total [00004] image file nums => [1980]
# split nums =>  396
# total move nums =>  396
# ========================================================================
# ========================================================================
# total [00024] image file nums => [270]
# split nums =>  54
# total move nums =>  54
# ========================================================================
# ========================================================================
# total [00019] image file nums => [210]
# split nums =>  42
# total move nums =>  42
# ========================================================================
# ========================================================================
# total [00006] image file nums => [420]
# split nums =>  84
# total move nums =>  84
# ========================================================================
# ========================================================================
# total [00034] image file nums => [420]
# split nums =>  84
# total move nums =>  84
# ========================================================================
# ========================================================================
# total [00028] image file nums => [540]
# split nums =>  108
# total move nums =>  108
# ========================================================================
# ========================================================================
# total [00033] image file nums => [689]
# split nums =>  137
# total move nums =>  137
# ========================================================================
# ========================================================================
# total [00010] image file nums => [2010]
# split nums =>  402
# total move nums =>  402
# ========================================================================
# ========================================================================
# total [00000] image file nums => [210]
# split nums =>  42
# total move nums =>  42
# ========================================================================
# ========================================================================
# total [00013] image file nums => [2160]
# split nums =>  432
# total move nums =>  432
# ========================================================================
# ========================================================================
# total [00032] image file nums => [240]
# split nums =>  48
# total move nums =>  48
# ========================================================================
# ========================================================================
# total [00018] image file nums => [1200]
# split nums =>  240
# total move nums =>  240
# ========================================================================
# ========================================================================
# total [00003] image file nums => [1410]
# split nums =>  282
# total move nums =>  282
# ========================================================================
# ========================================================================
# total [00017] image file nums => [1110]
# split nums =>  222
# total move nums =>  222
# ========================================================================
# ========================================================================
# total [00041] image file nums => [240]
# split nums =>  48
# total move nums =>  48
# ========================================================================
# ========================================================================
# total [00008] image file nums => [1410]
# split nums =>  282
# total move nums =>  282
# ========================================================================
# ========================================================================
# total [00039] image file nums => [300]
# split nums =>  60
# total move nums =>  60
# ========================================================================
# ========================================================================
# total [00035] image file nums => [1200]
# split nums =>  240
# total move nums =>  240
# ========================================================================
# ========================================================================
# total [00011] image file nums => [1320]
# split nums =>  264
# total move nums =>  264
# ========================================================================
# ========================================================================
# total [00038] image file nums => [2070]
# split nums =>  414
# total move nums =>  414
# ========================================================================
# ========================================================================
# total [00031] image file nums => [780]
# split nums =>  156
# total move nums =>  156
# ========================================================================
# ========================================================================
# total [00007] image file nums => [1440]
# split nums =>  288
# total move nums =>  288
# ========================================================================
# ========================================================================
# total [00037] image file nums => [210]
# split nums =>  42
# total move nums =>  42
# ========================================================================
# ========================================================================
# total [00002] image file nums => [2250]
# split nums =>  450
# total move nums =>  450
# ========================================================================
# ========================================================================
# total [00020] image file nums => [360]
# split nums =>  72
# total move nums =>  72
# ========================================================================
# ========================================================================
# total [00014] image file nums => [780]
# split nums =>  156
# total move nums =>  156
# ========================================================================
# ========================================================================
# total [00012] image file nums => [2100]
# split nums =>  420
# total move nums =>  420
# ========================================================================
# ========================================================================
# total [00009] image file nums => [1470]
# split nums =>  294
# total move nums =>  294
# ========================================================================
# ========================================================================
# total [00029] image file nums => [270]
# split nums =>  54
# total move nums =>  54
# ========================================================================
# ========================================================================
# total [00005] image file nums => [1860]
# split nums =>  372
# total move nums =>  372
# ========================================================================
# ========================================================================
# total [00021] image file nums => [330]
# split nums =>  66
# total move nums =>  66
# ========================================================================
# ========================================================================
# total [00030] image file nums => [450]
# split nums =>  90
# total move nums =>  90
# ========================================================================
# ========================================================================
# total [00040] image file nums => [360]
# split nums =>  72
# total move nums =>  72
# ========================================================================
# ========================================================================
# total [00027] image file nums => [240]
# split nums =>  48
# total move nums =>  48
# ========================================================================

# %% [markdown]
# # 검증

# %%
src_root_dir = '/content/GTSRB/train'
dst_root_dir = '/content/GTSRB/test'

train_label_name_list = os.listdir(src_root_dir)
test_label_name_list = os.listdir(dst_root_dir)

train_label_name_list.sort()
test_label_name_list.sort()

if train_label_name_list != test_label_name_list:
  print('error !')
else:
  print(len(train_label_name_list),len(test_label_name_list))

for label_name in train_label_name_list:

  train_data_nums = len(os.listdir(os.path.join(src_root_dir,label_name)))
  test_data_nums = len(os.listdir(os.path.join(dst_root_dir,label_name)))

  print('[%s] | train => [%s], test => [%s]'%(label_name, train_data_nums, test_data_nums))
  print('========================================================')
# Out:
# 43 43
# [00000] | train => [169], test => [42]
# ========================================================
# [00001] | train => [1777], test => [444]
# ========================================================
# [00002] | train => [1801], test => [450]
# ========================================================
# [00003] | train => [1129], test => [282]
# ========================================================
# [00004] | train => [1585], test => [396]
# ========================================================
# [00005] | train => [1489], test => [372]
# ========================================================
# [00006] | train => [337], test => [84]
# ========================================================
# [00007] | train => [1153], test => [288]
# ========================================================
# [00008] | train => [1129], test => [282]
# ========================================================
# [00009] | train => [1177], test => [294]
# ========================================================
# [00010] | train => [1609], test => [402]
# ========================================================
# [00011] | train => [1057], test => [264]
# ========================================================
# [00012] | train => [1681], test => [420]
# ========================================================
# [00013] | train => [1729], test => [432]
# ========================================================
# [00014] | train => [625], test => [156]
# ========================================================
# [00015] | train => [505], test => [126]
# ========================================================
# [00016] | train => [337], test => [84]
# ========================================================
# [00017] | train => [889], test => [222]
# ========================================================
# [00018] | train => [961], test => [240]
# ========================================================
# [00019] | train => [169], test => [42]
# ========================================================
# [00020] | train => [289], test => [72]
# ========================================================
# [00021] | train => [265], test => [66]
# ========================================================
# [00022] | train => [313], test => [78]
# ========================================================
# [00023] | train => [409], test => [102]
# ========================================================
# [00024] | train => [217], test => [54]
# ========================================================
# [00025] | train => [1201], test => [300]
# ========================================================
# [00026] | train => [481], test => [120]
# ========================================================
# [00027] | train => [193], test => [48]
# ========================================================
# [00028] | train => [433], test => [108]
# ========================================================
# [00029] | train => [217], test => [54]
# ========================================================
# [00030] | train => [361], test => [90]
# ========================================================
# [00031] | train => [625], test => [156]
# ========================================================
# [00032] | train => [193], test => [48]
# ========================================================
# [00033] | train => [553], test => [137]
# ========================================================
# [00034] | train => [337], test => [84]
# ========================================================
# [00035] | train => [961], test => [240]
# ========================================================
# [00036] | train => [313], test => [78]
# ========================================================
# [00037] | train => [169], test => [42]
# ========================================================
# [00038] | train => [1657], test => [414]
# ========================================================
# [00039] | train => [241], test => [60]
# ========================================================
# [00040] | train => [289], test => [72]
# ========================================================
# [00041] | train => [193], test => [48]
# ========================================================
# [00042] | train => [193], test => [48]
# ========================================================

# %% [markdown]
# # Train 디렉토리에서 iamge, label로 numpy 생성

# %%
import cv2
import numpy as np

train_image_list = []
train_label_list = []

train_base_dir = '/content/GTSRB/train/'
train_label_name_list = os.listdir(train_base_dir)

for train_label_name in train_label_name_list:
    file_path = os.path.join(train_base_dir, train_label_name)

    train_img_file_list = glob(file_path + '/*.ppm')

    for train_img_file in train_img_file_list:
        src_img = cv2.imread(train_img_file, cv2.IMREAD_COLOR)
        src_img = cv2.resize(src_img, dsize=(32,32))
        src_img = cv2.cvtColor(src_img, cv2.COLOR_BGR2RGB)   

        if src_img is None:
            continue
        train_image_list.append(src_img)
        train_label_list.append(float(train_label_name))

x_train = np.array(train_image_list).astype('float32')
y_train = np.array(train_label_list).astype('float32')

print('x_train.shape = {}, y_train.shape = {}'.format(x_train.shape, y_train.shape))
# Out:
# x_train.shape = (31368, 32, 32, 3), y_train.shape = (31368,)

# %% [markdown]
# # Test 디렉토리에서 iamge, label로 numpy 생성

# %%
import cv2
import numpy as np

test_image_list = []
test_label_list = []

test_base_dir = '/content/GTSRB/test/'
test_label_name_list = os.listdir(test_base_dir)

for test_label_name in test_label_name_list:
    file_path = os.path.join(test_base_dir, test_label_name)

    test_img_file_list = glob(file_path + '/*.ppm')

    for test_img_file in test_img_file_list:
        src_img = cv2.imread(test_img_file, cv2.IMREAD_COLOR)
        src_img = cv2.resize(src_img, dsize=(32,32))
        src_img = cv2.cvtColor(src_img, cv2.COLOR_BGR2RGB)   

        if src_img is None:
            continue
        test_image_list.append(src_img)
        test_label_list.append(float(test_label_name))

x_test = np.array(test_image_list).astype('float32')
y_test = np.array(test_label_list).astype('float32')

print('x_test.shape = {}, y_test.shape = {}'.format(x_test.shape, y_test.shape))
# Out:
# x_test.shape = (7841, 32, 32, 3), y_test.shape = (7841,)

# %% [markdown]
# # 정규화

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %% [markdown]
# # Sample 이미지 출력

# %%
import matplotlib.pyplot as plt

random_index = np.random.randint(0,len(x_train),16)

plt.figure(figsize=(8,8))
for pos in range(len(random_index)):
    plt.subplot(4,4,pos+1)
    plt.axis('off')
    train_img_index = random_index[pos]
    plt.imshow(x_train[train_img_index])

plt.tight_layout()
plt.show()

# %% [markdown]
# # 모델링

# %%
import tensorflow as tf

from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Dropout, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

# %%
n_classes = len(os.listdir('/content/GTSRB/train/'))

model = Sequential()
model.add(Conv2D(input_shape=(32,32,3),kernel_size=3, filters=32, activation='relu',padding='SAME'))
model.add(MaxPool2D(pool_size=(2,2),padding='SAME'))
model.add(Dropout(0.25))

model.add(Conv2D(kernel_size=3, filters=32, activation='relu',padding='SAME'))
model.add(MaxPool2D(pool_size=(2,2),padding='SAME'))
model.add(Dropout(0.25))

model.add(Conv2D(kernel_size=3, filters=32, activation='relu',padding='SAME'))

model.add(Flatten())
model.add(Dense(n_classes,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 32)          0
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 32)          9248
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 43)                88107
#
# =================================================================
# Total params: 107,499
# Trainable params: 107,499
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(), 
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from datetime import datetime

save_dir = '/content/GTSRB/Models'
save_file_name = save_dir+'/GTSRB_Native_Colab.h5'

if not os.path.exists(save_dir):
    os.mkdir(save_dir)
    print('Model save dir created !')

checkpoint = ModelCheckpoint(save_file_name,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True,
                             mode='auto')
earlystopping = EarlyStopping(monitor='val_loss',
                              patience=5)

hist = model.fit(x_train,y_train, 
                 epochs=30, batch_size=32, 
                 validation_data=(x_test,y_test),
                 callbacks=[checkpoint,earlystopping])
# Out:
# Model save dir created !
# Epoch 1/30
# 981/981 [==============================] - ETA: 0s - loss: 1.3502 - accuracy: 0.6059
# Epoch 1: val_loss improved from inf to 0.34994, saving model to /content/GTSRB/Models/GTSRB_Native_Colab.h5
# 981/981 [==============================] - 18s 8ms/step - loss: 1.3502 - accuracy: 0.6059 - val_loss: 0.3499 - val_accuracy: 0.8885
# Epoch 2/30
# 978/981 [============================>.] - ETA: 0s - loss: 0.2933 - accuracy: 0.9089
# Epoch 2: val_loss improved from 0.34994 to 0.14104, saving model to /content/GTSRB/Models/GTSRB_Native_Colab.h5
# 981/981 [==============================] - 8s 8ms/step - loss: 0.2932 - accuracy: 0.9090 - val_loss: 0.1410 - val_accuracy: 0.9602
# Epoch 3/30
# 974/981 [============================>.] - ETA: 0s - loss: 0.1698 - accuracy: 0.9484
# Epoch 3: val_loss improved from 0.14104 to 0.11036, saving model to /content/GTSRB/Models/GTSRB_Native_Colab.h5
# 981/981 [==============================] - 8s 8ms/step - loss: 0.1696 - accuracy: 0.9484 - val_loss: 0.1104 - val_accuracy: 0.9676
# Epoch 4/30
# 981/981 [==============================] - ETA: 0s - loss: 0.1160 - accuracy: 0.9645
# Epoch 4: val_loss improved from 0.11036 to 0.06698, saving model to /content/GTSRB/Models/GTSRB_Native_Colab.h5
# 981/981 [==============================] - 7s 7ms/step - loss: 0.1160 - accuracy: 0.9645 - val_loss: 0.0670 - val_accuracy: 0.9827
# Epoch 5/30
# 979/981 [============================>.] - ETA: 0s - loss: 0.0848 - accuracy: 0.9735
# Epoch 5: val_loss improved from 0.06698 to 0.05969, saving model to /content/GTSRB/Models/GTSRB_Native_Colab.h5
# 981/981 [==============================] - 8s 8ms/step - loss: 0.0847 - accuracy: 0.9735 - val_loss: 0.0597 - val_accuracy: 0.9833
# Epoch 6/30
# 974/981 [============================>.] - ETA: 0s - loss: 0.0743 - accuracy: 0.9767
# Epoch 6: val_loss improved from 0.05969 to 0.05404, saving model to /content/GTSRB/Models/GTSRB_Native_Colab.h5
# 981/981 [==============================] - 8s 8ms/step - loss: 0.0745 - accuracy: 0.9766 - val_loss: 0.0540 - val_accuracy: 0.9852
# Epoch 7/30
# 978/981 [============================>.] - ETA: 0s - loss: 0.0596 - accuracy: 0.9807
# Epoch 7: val_loss improved from 0.05404 to 0.04612, saving model to /content/GTSRB/Models/GTSRB_Native_Colab.h5
# 981/981 [==============================] - 7s 7ms/step - loss: 0.0596 - accuracy: 0.9807 - val_loss: 0.0461 - val_accuracy: 0.9876
# Epoch 8/30
# 979/981 [============================>.] - ETA: 0s - loss: 0.0513 - accuracy: 0.9836
# Epoch 8: val_loss improved from 0.04612 to 0.04592, saving model to /content/GTSRB/Models/GTSRB_Native_Colab.h5
# 981/981 [==============================] - 7s 7ms/step - loss: 0.0513 - accuracy: 0.9836 - val_loss: 0.0459 - val_accuracy: 0.9869
# Epoch 9/30
# 980/981 [============================>.] - ETA: 0s - loss: 0.0475 - accuracy: 0.9854
# Epoch 9: val_loss improved from 0.04592 to 0.03752, saving model to /content/GTSRB/Models/GTSRB_Native_Colab.h5
# 981/981 [==============================] - 7s 8ms/step - loss: 0.0474 - accuracy: 0.9854 - val_loss: 0.0375 - val_accuracy: 0.9894
# Epoch 10/30
# 981/981 [==============================] - ETA: 0s - loss: 0.0420 - accuracy: 0.9864
# Epoch 10: val_loss did not improve from 0.03752
# 981/981 [==============================] - 7s 7ms/step - loss: 0.0420 - accuracy: 0.9864 - val_loss: 0.0580 - val_accuracy: 0.9844
# Epoch 11/30
# 981/981 [==============================] - ETA: 0s - loss: 0.0396 - accuracy: 0.9873
# Epoch 11: val_loss did not improve from 0.03752
# 981/981 [==============================] - 7s 7ms/step - loss: 0.0396 - accuracy: 0.9873 - val_loss: 0.0404 - val_accuracy: 0.9901
# Epoch 12/30
# 977/981 [============================>.] - ETA: 0s - loss: 0.0385 - accuracy: 0.9878
# Epoch 12: val_loss did not improve from 0.03752
# 981/981 [==============================] - 8s 8ms/step - loss: 0.0384 - accuracy: 0.9878 - val_loss: 0.0418 - val_accuracy: 0.9880
# Epoch 13/30
# 977/981 [============================>.] - ETA: 0s - loss: 0.0327 - accuracy: 0.9893
# Epoch 13: val_loss improved from 0.03752 to 0.03689, saving model to /content/GTSRB/Models/GTSRB_Native_Colab.h5
# 981/981 [==============================] - 7s 8ms/step - loss: 0.0328 - accuracy: 0.9893 - val_loss: 0.0369 - val_accuracy: 0.9904
# Epoch 14/30
# 977/981 [============================>.] - ETA: 0s - loss: 0.0289 - accuracy: 0.9907
# Epoch 14: val_loss improved from 0.03689 to 0.03544, saving model to /content/GTSRB/Models/GTSRB_Native_Colab.h5
# 981/981 [==============================] - 8s 8ms/step - loss: 0.0290 - accuracy: 0.9906 - val_loss: 0.0354 - val_accuracy: 0.9913
# Epoch 15/30
# 978/981 [============================>.] - ETA: 0s - loss: 0.0296 - accuracy: 0.9901
# Epoch 15: val_loss improved from 0.03544 to 0.03483, saving model to /content/GTSRB/Models/GTSRB_Native_Colab.h5
# 981/981 [==============================] - 8s 8ms/step - loss: 0.0297 - accuracy: 0.9901 - val_loss: 0.0348 - val_accuracy: 0.9911
# Epoch 16/30
# 974/981 [============================>.] - ETA: 0s - loss: 0.0346 - accuracy: 0.9889
# Epoch 16: val_loss did not improve from 0.03483
# 981/981 [==============================] - 8s 8ms/step - loss: 0.0346 - accuracy: 0.9889 - val_loss: 0.0383 - val_accuracy: 0.9911
# Epoch 17/30
# 976/981 [============================>.] - ETA: 0s - loss: 0.0266 - accuracy: 0.9908
# Epoch 17: val_loss improved from 0.03483 to 0.03171, saving model to /content/GTSRB/Models/GTSRB_Native_Colab.h5
# 981/981 [==============================] - 7s 8ms/step - loss: 0.0265 - accuracy: 0.9909 - val_loss: 0.0317 - val_accuracy: 0.9931
# Epoch 18/30
# 976/981 [============================>.] - ETA: 0s - loss: 0.0263 - accuracy: 0.9914
# Epoch 18: val_loss did not improve from 0.03171
# 981/981 [==============================] - 8s 8ms/step - loss: 0.0263 - accuracy: 0.9914 - val_loss: 0.0346 - val_accuracy: 0.9906
# Epoch 19/30
# 977/981 [============================>.] - ETA: 0s - loss: 0.0284 - accuracy: 0.9911
# Epoch 19: val_loss did not improve from 0.03171
# 981/981 [==============================] - 7s 8ms/step - loss: 0.0283 - accuracy: 0.9912 - val_loss: 0.0356 - val_accuracy: 0.9908
# Epoch 20/30
# 974/981 [============================>.] - ETA: 0s - loss: 0.0260 - accuracy: 0.9915
# Epoch 20: val_loss did not improve from 0.03171
# 981/981 [==============================] - 8s 8ms/step - loss: 0.0262 - accuracy: 0.9914 - val_loss: 0.0368 - val_accuracy: 0.9918
# Epoch 21/30
# 974/981 [============================>.] - ETA: 0s - loss: 0.0266 - accuracy: 0.9914
# Epoch 21: val_loss improved from 0.03171 to 0.02936, saving model to /content/GTSRB/Models/GTSRB_Native_Colab.h5
# 981/981 [==============================] - 8s 8ms/step - loss: 0.0265 - accuracy: 0.9915 - val_loss: 0.0294 - val_accuracy: 0.9907
# Epoch 22/30
# 975/981 [============================>.] - ETA: 0s - loss: 0.0255 - accuracy: 0.9924
# Epoch 22: val_loss did not improve from 0.02936
# 981/981 [==============================] - 8s 8ms/step - loss: 0.0254 - accuracy: 0.9923 - val_loss: 0.0306 - val_accuracy: 0.9923
# Epoch 23/30
# 978/981 [============================>.] - ETA: 0s - loss: 0.0285 - accuracy: 0.9913
# Epoch 23: val_loss did not improve from 0.02936
# 981/981 [==============================] - 8s 8ms/step - loss: 0.0287 - accuracy: 0.9913 - val_loss: 0.0328 - val_accuracy: 0.9912
# Epoch 24/30
# 978/981 [============================>.] - ETA: 0s - loss: 0.0205 - accuracy: 0.9939
# Epoch 24: val_loss did not improve from 0.02936
# 981/981 [==============================] - 8s 8ms/step - loss: 0.0205 - accuracy: 0.9939 - val_loss: 0.0386 - val_accuracy: 0.9916
# Epoch 25/30
# 974/981 [============================>.] - ETA: 0s - loss: 0.0226 - accuracy: 0.9932
# Epoch 25: val_loss did not improve from 0.02936
# 981/981 [==============================] - 7s 8ms/step - loss: 0.0226 - accuracy: 0.9932 - val_loss: 0.0484 - val_accuracy: 0.9901
# Epoch 26/30
# 975/981 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 0.9926
# Epoch 26: val_loss did not improve from 0.02936
# 981/981 [==============================] - 7s 7ms/step - loss: 0.0245 - accuracy: 0.9927 - val_loss: 0.0363 - val_accuracy: 0.9921

# %%
model.evaluate(x_test,y_test)
# Out:
# 246/246 [==============================] - 1s 4ms/step - loss: 0.0363 - accuracy: 0.9921
# [0.03633246198296547, 0.9920928478240967]

# %%
plt.title('Accuracy Trend')
plt.grid()
plt.xlabel('Epcohs')
plt.ylabel('Accuracy')
plt.plot(hist.history['accuracy'],label='train')
plt.plot(hist.history['val_accuracy'],label='validation')
plt.legend(loc='best')
plt.show()

# %%
plt.title('Loss Trend')
plt.grid()
plt.xlabel('Epcohs')
plt.ylabel('Loss')
plt.plot(hist.history['loss'],label='train')
plt.plot(hist.history['val_loss'],label='validation')
plt.legend(loc='best')
plt.show()
