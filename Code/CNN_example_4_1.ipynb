# %%
import tensorflow as tf

from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPool2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist

import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.8.0

# %%
(x_train, t_train), (x_test, t_test) = mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

print('x_train.shape : {0}, x_test.shape : {1}'.format(x_train.shape, x_test.shape))
print('t_train.shape : {0}, t_test.shape : {1}'.format(t_train.shape, t_test.shape))
# Out:
# x_train.shape : (60000, 28, 28), x_test.shape : (10000, 28, 28)
# t_train.shape : (60000,), t_test.shape : (10000,)

# %%
model = Sequential()

model.add(Conv2D(input_shape=(28,28,1),
                kernel_size=3, filters=32,
                 strides=(1,1), activation='relu', use_bias=True, padding='SAME'))
model.add(MaxPool2D(pool_size=(2,2),padding='SAME'))

model.add(Conv2D(kernel_size=4, filters=64,
                 strides=(1,1), activation='relu', use_bias=True, padding='SAME'))
model.add(MaxPool2D(pool_size=(2,2),padding='SAME'))

model.add(Flatten())

model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 28, 28, 32)        320
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 64)        32832
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 3136)              0
#
#  dense_2 (Dense)             (None, 10)                31370
#
# =================================================================
# Total params: 64,522
# Trainable params: 64,522
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_train.reshape(-1,28,28,1), t_train,
                 batch_size=50, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 960/960 [==============================] - 9s 9ms/step - loss: 0.1765 - accuracy: 0.9460 - val_loss: 0.0572 - val_accuracy: 0.9831
# Epoch 2/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0538 - accuracy: 0.9835 - val_loss: 0.0495 - val_accuracy: 0.9852
# Epoch 3/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0371 - accuracy: 0.9885 - val_loss: 0.0460 - val_accuracy: 0.9862
# Epoch 4/50
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0291 - accuracy: 0.9912 - val_loss: 0.0360 - val_accuracy: 0.9898
# Epoch 5/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0222 - accuracy: 0.9927 - val_loss: 0.0424 - val_accuracy: 0.9883
# Epoch 6/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0181 - accuracy: 0.9942 - val_loss: 0.0375 - val_accuracy: 0.9887
# Epoch 7/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0135 - accuracy: 0.9958 - val_loss: 0.0436 - val_accuracy: 0.9886
# Epoch 8/50
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0123 - accuracy: 0.9956 - val_loss: 0.0376 - val_accuracy: 0.9903
# Epoch 9/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0083 - accuracy: 0.9973 - val_loss: 0.0388 - val_accuracy: 0.9898
# Epoch 10/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0077 - accuracy: 0.9972 - val_loss: 0.0447 - val_accuracy: 0.9888
# Epoch 11/50
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.0444 - val_accuracy: 0.9900
# Epoch 12/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0055 - accuracy: 0.9981 - val_loss: 0.0478 - val_accuracy: 0.9894
# Epoch 13/50
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.0469 - val_accuracy: 0.9896
# Epoch 14/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0044 - accuracy: 0.9984 - val_loss: 0.0573 - val_accuracy: 0.9881
# Epoch 15/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 0.0611 - val_accuracy: 0.9892
# Epoch 16/50
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0036 - accuracy: 0.9988 - val_loss: 0.0849 - val_accuracy: 0.9870
# Epoch 17/50
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.0521 - val_accuracy: 0.9904
# Epoch 18/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.0520 - val_accuracy: 0.9901
# Epoch 19/50
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.0546 - val_accuracy: 0.9898
# Epoch 20/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0607 - val_accuracy: 0.9904
# Epoch 21/50
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0548 - val_accuracy: 0.9909
# Epoch 22/50
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0028 - accuracy: 0.9989 - val_loss: 0.0605 - val_accuracy: 0.9899
# Epoch 23/50
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.0671 - val_accuracy: 0.9883
# Epoch 24/50
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0585 - val_accuracy: 0.9894
# Epoch 25/50
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0016 - accuracy: 0.9993 - val_loss: 0.0615 - val_accuracy: 0.9906
# Epoch 26/50
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0035 - accuracy: 0.9987 - val_loss: 0.0651 - val_accuracy: 0.9906
# Epoch 27/50
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0623 - val_accuracy: 0.9902
# Epoch 28/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.0605 - val_accuracy: 0.9905
# Epoch 29/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0570 - val_accuracy: 0.9914
# Epoch 30/50
# 960/960 [==============================] - 8s 8ms/step - loss: 1.5068e-04 - accuracy: 1.0000 - val_loss: 0.0614 - val_accuracy: 0.9912
# Epoch 31/50
# 960/960 [==============================] - 8s 8ms/step - loss: 1.0570e-04 - accuracy: 1.0000 - val_loss: 0.0639 - val_accuracy: 0.9918
# Epoch 32/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.0618 - val_accuracy: 0.9911
# Epoch 33/50
# 960/960 [==============================] - 8s 8ms/step - loss: 5.6289e-04 - accuracy: 0.9998 - val_loss: 0.0726 - val_accuracy: 0.9899
# Epoch 34/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.0646 - val_accuracy: 0.9914
# Epoch 35/50
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.0636 - val_accuracy: 0.9921
# Epoch 36/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0755 - val_accuracy: 0.9911
# Epoch 37/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0685 - val_accuracy: 0.9908
# Epoch 38/50
# 960/960 [==============================] - 7s 7ms/step - loss: 2.7360e-04 - accuracy: 0.9999 - val_loss: 0.0722 - val_accuracy: 0.9900
# Epoch 39/50
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.0837 - val_accuracy: 0.9893
# Epoch 40/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0816 - val_accuracy: 0.9892
# Epoch 41/50
# 960/960 [==============================] - 7s 7ms/step - loss: 5.8616e-04 - accuracy: 0.9999 - val_loss: 0.0690 - val_accuracy: 0.9909
# Epoch 42/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0764 - val_accuracy: 0.9900
# Epoch 43/50
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.0802 - val_accuracy: 0.9893
# Epoch 44/50
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0747 - val_accuracy: 0.9912
# Epoch 45/50
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0761 - val_accuracy: 0.9908
# Epoch 46/50
# 960/960 [==============================] - 7s 7ms/step - loss: 3.7428e-04 - accuracy: 0.9999 - val_loss: 0.0825 - val_accuracy: 0.9903
# Epoch 47/50
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0960 - val_accuracy: 0.9888
# Epoch 48/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0019 - accuracy: 0.9993 - val_loss: 0.0773 - val_accuracy: 0.9908
# Epoch 49/50
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.0729 - val_accuracy: 0.9915
# Epoch 50/50
# 960/960 [==============================] - 7s 7ms/step - loss: 4.2891e-04 - accuracy: 0.9998 - val_loss: 0.0771 - val_accuracy: 0.9911

# %%
model.evaluate(x_test.reshape(-1,28,28,1), t_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0714 - accuracy: 0.9905
# [0.07137450575828552, 0.9904999732971191]

# %%
ret_val = model.predict(x_test.reshape(-1,28,28,1))

print(f'ret_val.type : {type(ret_val)}, ret_val.shape : {ret_val.shape}')

predicted_val = np.argmax(ret_val,axis=1)

predicted_comp_list = np.equal(predicted_val, t_test)

index_label_prediction = [ [index, t_test[index], predicted_val[index]] for index, result in enumerate(predicted_comp_list) if result == False ]

print(len(index_label_prediction))
# Out:
# ret_val.type : <class 'numpy.ndarray'>, ret_val.shape : (10000, 10)
# 95

# %%
false_data_index = np.random.randint(len(index_label_prediction))

mnist_index = index_label_prediction[false_data_index][0]
label = index_label_prediction[false_data_index][1]
prediction = index_label_prediction[false_data_index][2]

title_str = f'index = {false_data_index}, label = {label}, pred = {prediction}'

img = x_test[mnist_index].reshape(28,28)

plt.title(title_str)
plt.imshow(img,cmap='gray')
plt.show()
