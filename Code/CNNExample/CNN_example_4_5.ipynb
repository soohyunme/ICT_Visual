# %%
import tensorflow as tf

from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPool2D, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist

import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.8.0

# %%
(x_train, t_train), (x_test, t_test) = mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

print('x_train.shape : {0}, x_test.shape : {1}'.format(x_train.shape, x_test.shape))
print('t_train.shape : {0}, t_test.shape : {1}'.format(t_train.shape, t_test.shape))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# x_train.shape : (60000, 28, 28), x_test.shape : (10000, 28, 28)
# t_train.shape : (60000,), t_test.shape : (10000,)

# %%
model = Sequential()

model.add(Conv2D(input_shape=(28,28,1),
                kernel_size=5, filters=32,
                 strides=(1,1), activation='relu', use_bias=True, padding='SAME'))
model.add(MaxPool2D(pool_size=(2,2),padding='SAME'))
model.add(Dropout(0.5))

model.add(Conv2D(kernel_size=5, filters=64,
                 strides=(1,1), activation='relu', use_bias=True, padding='SAME'))
model.add(MaxPool2D(pool_size=(2,2),padding='SAME'))
model.add(Dropout(0.5))

model.add(Flatten())

model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        832
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  dropout (Dropout)           (None, 14, 14, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 64)        51264
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 7, 7, 64)          0
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 10)                31370
#
# =================================================================
# Total params: 83,466
# Trainable params: 83,466
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_train.reshape(-1,28,28,1), t_train,
                 batch_size=50, epochs=50, validation_data=(x_test.reshape(-1,28,28,1), t_test))
# Out:
# Epoch 1/50
# 1200/1200 [==============================] - 16s 4ms/step - loss: 0.2275 - accuracy: 0.9283 - val_loss: 0.0582 - val_accuracy: 0.9825
# Epoch 2/50
# 1200/1200 [==============================] - 5s 4ms/step - loss: 0.0831 - accuracy: 0.9736 - val_loss: 0.0386 - val_accuracy: 0.9885
# Epoch 3/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0656 - accuracy: 0.9794 - val_loss: 0.0316 - val_accuracy: 0.9908
# Epoch 4/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0565 - accuracy: 0.9819 - val_loss: 0.0338 - val_accuracy: 0.9897
# Epoch 5/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0511 - accuracy: 0.9837 - val_loss: 0.0260 - val_accuracy: 0.9917
# Epoch 6/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0466 - accuracy: 0.9856 - val_loss: 0.0255 - val_accuracy: 0.9914
# Epoch 7/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0436 - accuracy: 0.9862 - val_loss: 0.0270 - val_accuracy: 0.9912
# Epoch 8/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0403 - accuracy: 0.9875 - val_loss: 0.0236 - val_accuracy: 0.9924
# Epoch 9/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0391 - accuracy: 0.9877 - val_loss: 0.0216 - val_accuracy: 0.9927
# Epoch 10/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0370 - accuracy: 0.9878 - val_loss: 0.0209 - val_accuracy: 0.9925
# Epoch 11/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0385 - accuracy: 0.9882 - val_loss: 0.0234 - val_accuracy: 0.9929
# Epoch 12/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0353 - accuracy: 0.9882 - val_loss: 0.0217 - val_accuracy: 0.9929
# Epoch 13/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0327 - accuracy: 0.9895 - val_loss: 0.0216 - val_accuracy: 0.9931
# Epoch 14/50
# 1200/1200 [==============================] - 5s 4ms/step - loss: 0.0328 - accuracy: 0.9894 - val_loss: 0.0205 - val_accuracy: 0.9935
# Epoch 15/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0302 - accuracy: 0.9904 - val_loss: 0.0225 - val_accuracy: 0.9922
# Epoch 16/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0321 - accuracy: 0.9896 - val_loss: 0.0196 - val_accuracy: 0.9929
# Epoch 17/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0299 - accuracy: 0.9899 - val_loss: 0.0205 - val_accuracy: 0.9936
# Epoch 18/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0301 - accuracy: 0.9905 - val_loss: 0.0198 - val_accuracy: 0.9936
# Epoch 19/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0291 - accuracy: 0.9911 - val_loss: 0.0191 - val_accuracy: 0.9939
# Epoch 20/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0297 - accuracy: 0.9906 - val_loss: 0.0206 - val_accuracy: 0.9937
# Epoch 21/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0289 - accuracy: 0.9906 - val_loss: 0.0203 - val_accuracy: 0.9937
# Epoch 22/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0291 - accuracy: 0.9904 - val_loss: 0.0224 - val_accuracy: 0.9936
# Epoch 23/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0260 - accuracy: 0.9917 - val_loss: 0.0196 - val_accuracy: 0.9943
# Epoch 24/50
# 1200/1200 [==============================] - 5s 4ms/step - loss: 0.0270 - accuracy: 0.9912 - val_loss: 0.0208 - val_accuracy: 0.9937
# Epoch 25/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0267 - accuracy: 0.9912 - val_loss: 0.0195 - val_accuracy: 0.9932
# Epoch 26/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0273 - accuracy: 0.9910 - val_loss: 0.0217 - val_accuracy: 0.9931
# Epoch 27/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0263 - accuracy: 0.9918 - val_loss: 0.0205 - val_accuracy: 0.9934
# Epoch 28/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0258 - accuracy: 0.9916 - val_loss: 0.0192 - val_accuracy: 0.9941
# Epoch 29/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0255 - accuracy: 0.9919 - val_loss: 0.0174 - val_accuracy: 0.9947
# Epoch 30/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0254 - accuracy: 0.9917 - val_loss: 0.0189 - val_accuracy: 0.9941
# Epoch 31/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0247 - accuracy: 0.9918 - val_loss: 0.0185 - val_accuracy: 0.9942
# Epoch 32/50
# 1200/1200 [==============================] - 5s 4ms/step - loss: 0.0284 - accuracy: 0.9911 - val_loss: 0.0182 - val_accuracy: 0.9948
# Epoch 33/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0250 - accuracy: 0.9919 - val_loss: 0.0173 - val_accuracy: 0.9948
# Epoch 34/50
# 1200/1200 [==============================] - 5s 4ms/step - loss: 0.0253 - accuracy: 0.9916 - val_loss: 0.0206 - val_accuracy: 0.9936
# Epoch 35/50
# 1200/1200 [==============================] - 6s 5ms/step - loss: 0.0265 - accuracy: 0.9915 - val_loss: 0.0203 - val_accuracy: 0.9935
# Epoch 36/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0239 - accuracy: 0.9924 - val_loss: 0.0210 - val_accuracy: 0.9942
# Epoch 37/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0271 - accuracy: 0.9912 - val_loss: 0.0202 - val_accuracy: 0.9932
# Epoch 38/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0238 - accuracy: 0.9924 - val_loss: 0.0182 - val_accuracy: 0.9945
# Epoch 39/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0238 - accuracy: 0.9928 - val_loss: 0.0209 - val_accuracy: 0.9937
# Epoch 40/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0233 - accuracy: 0.9925 - val_loss: 0.0182 - val_accuracy: 0.9944
# Epoch 41/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0253 - accuracy: 0.9921 - val_loss: 0.0195 - val_accuracy: 0.9943
# Epoch 42/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0241 - accuracy: 0.9924 - val_loss: 0.0175 - val_accuracy: 0.9938
# Epoch 43/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0226 - accuracy: 0.9924 - val_loss: 0.0196 - val_accuracy: 0.9934
# Epoch 44/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0242 - accuracy: 0.9924 - val_loss: 0.0186 - val_accuracy: 0.9941
# Epoch 45/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0246 - accuracy: 0.9921 - val_loss: 0.0206 - val_accuracy: 0.9938
# Epoch 46/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0259 - accuracy: 0.9920 - val_loss: 0.0220 - val_accuracy: 0.9933
# Epoch 47/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0226 - accuracy: 0.9928 - val_loss: 0.0216 - val_accuracy: 0.9930
# Epoch 48/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0240 - accuracy: 0.9925 - val_loss: 0.0182 - val_accuracy: 0.9940
# Epoch 49/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0225 - accuracy: 0.9927 - val_loss: 0.0197 - val_accuracy: 0.9942
# Epoch 50/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0231 - accuracy: 0.9925 - val_loss: 0.0196 - val_accuracy: 0.9939

# %%
model.evaluate(x_test.reshape(-1,28,28,1), t_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0196 - accuracy: 0.9939
# [0.019573863595724106, 0.9939000010490417]

# %%
plt.subplot(121)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss Trends')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.subplot(122)
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy Trends')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
ret_val = model.predict(x_test.reshape(-1,28,28,1))

print(f'ret_val.type : {type(ret_val)}, ret_val.shape : {ret_val.shape}')

predicted_val = np.argmax(ret_val,axis=1)

predicted_comp_list = np.equal(predicted_val, t_test)

index_label_prediction = [ [index, t_test[index], predicted_val[index]] for index, result in enumerate(predicted_comp_list) if result == False ]

print(len(index_label_prediction))
# Out:
# ret_val.type : <class 'numpy.ndarray'>, ret_val.shape : (10000, 10)
# 61

# %%
false_data_index = np.random.randint(len(index_label_prediction))

mnist_index = index_label_prediction[false_data_index][0]
label = index_label_prediction[false_data_index][1]
prediction = index_label_prediction[false_data_index][2]

title_str = f'index = {false_data_index}, label = {label}, pred = {prediction}'

img = x_test[mnist_index].reshape(28,28)

plt.title(title_str)
plt.imshow(img,cmap='gray')
plt.show()
