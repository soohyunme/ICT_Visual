# %%
import tensorflow as tf

from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPool2D, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist

import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.8.0

# %%
(x_train, t_train), (x_test, t_test) = mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

print('x_train.shape : {0}, x_test.shape : {1}'.format(x_train.shape, x_test.shape))
print('t_train.shape : {0}, t_test.shape : {1}'.format(t_train.shape, t_test.shape))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# x_train.shape : (60000, 28, 28), x_test.shape : (10000, 28, 28)
# t_train.shape : (60000,), t_test.shape : (10000,)

# %%
model = Sequential()

# Convolution 1
model.add(Conv2D(input_shape=(28,28,1),
                kernel_size=5, filters=32,
                 strides=(1,1), activation='relu', use_bias=True, padding='SAME'))
model.add(MaxPool2D(pool_size=(2,2),padding='SAME'))

# Convolution 2
model.add(Conv2D(kernel_size=5, filters=32,
                 strides=(1,1), activation='relu', use_bias=True, padding='SAME'))
model.add(MaxPool2D(pool_size=(2,2),padding='SAME'))

# Convolution 3
model.add(Conv2D(kernel_size=5, filters=32,
                 strides=(1,1), activation='relu', use_bias=True, padding='SAME'))
model.add(MaxPool2D(pool_size=(2,2),padding='SAME'))

model.add(Flatten())

model.add(Dense(128, activation='relu'))

model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        832
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        25632
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 32)          25632
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 128)               65664
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 119,050
# Trainable params: 119,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_train.reshape(-1,28,28,1), t_train,
                 batch_size=50, epochs=50, validation_data=(x_test.reshape(-1,28,28,1), t_test))
# Out:
# Epoch 1/50
# 1200/1200 [==============================] - 21s 8ms/step - loss: 0.1521 - accuracy: 0.9545 - val_loss: 0.0443 - val_accuracy: 0.9861
# Epoch 2/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0457 - accuracy: 0.9858 - val_loss: 0.0449 - val_accuracy: 0.9869
# Epoch 3/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0326 - accuracy: 0.9898 - val_loss: 0.0323 - val_accuracy: 0.9903
# Epoch 4/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0247 - accuracy: 0.9923 - val_loss: 0.0246 - val_accuracy: 0.9911
# Epoch 5/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0206 - accuracy: 0.9935 - val_loss: 0.0289 - val_accuracy: 0.9901
# Epoch 6/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0168 - accuracy: 0.9945 - val_loss: 0.0354 - val_accuracy: 0.9896
# Epoch 7/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0141 - accuracy: 0.9952 - val_loss: 0.0311 - val_accuracy: 0.9902
# Epoch 8/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0113 - accuracy: 0.9963 - val_loss: 0.0287 - val_accuracy: 0.9907
# Epoch 9/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0122 - accuracy: 0.9959 - val_loss: 0.0256 - val_accuracy: 0.9919
# Epoch 10/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0084 - accuracy: 0.9972 - val_loss: 0.0296 - val_accuracy: 0.9914
# Epoch 11/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0108 - accuracy: 0.9965 - val_loss: 0.0284 - val_accuracy: 0.9923
# Epoch 12/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.0366 - val_accuracy: 0.9903
# Epoch 13/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 0.0367 - val_accuracy: 0.9898
# Epoch 14/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0075 - accuracy: 0.9977 - val_loss: 0.0322 - val_accuracy: 0.9924
# Epoch 15/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.0332 - val_accuracy: 0.9922
# Epoch 16/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0064 - accuracy: 0.9979 - val_loss: 0.0286 - val_accuracy: 0.9935
# Epoch 17/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.0343 - val_accuracy: 0.9916
# Epoch 18/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0059 - accuracy: 0.9982 - val_loss: 0.0478 - val_accuracy: 0.9912
# Epoch 19/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0061 - accuracy: 0.9981 - val_loss: 0.0585 - val_accuracy: 0.9889
# Epoch 20/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.0432 - val_accuracy: 0.9921
# Epoch 21/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0061 - accuracy: 0.9982 - val_loss: 0.0466 - val_accuracy: 0.9903
# Epoch 22/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0043 - accuracy: 0.9984 - val_loss: 0.0496 - val_accuracy: 0.9916
# Epoch 23/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0045 - accuracy: 0.9987 - val_loss: 0.0445 - val_accuracy: 0.9920
# Epoch 24/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0032 - accuracy: 0.9989 - val_loss: 0.0522 - val_accuracy: 0.9908
# Epoch 25/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.0532 - val_accuracy: 0.9911
# Epoch 26/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.0490 - val_accuracy: 0.9921
# Epoch 27/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0056 - accuracy: 0.9985 - val_loss: 0.0461 - val_accuracy: 0.9916
# Epoch 28/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0049 - accuracy: 0.9987 - val_loss: 0.0622 - val_accuracy: 0.9900
# Epoch 29/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.0565 - val_accuracy: 0.9910
# Epoch 30/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0557 - val_accuracy: 0.9918
# Epoch 31/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.0629 - val_accuracy: 0.9912
# Epoch 32/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0060 - accuracy: 0.9986 - val_loss: 0.0717 - val_accuracy: 0.9905
# Epoch 33/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.0607 - val_accuracy: 0.9921
# Epoch 34/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.0576 - val_accuracy: 0.9919
# Epoch 35/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0059 - accuracy: 0.9985 - val_loss: 0.0411 - val_accuracy: 0.9926
# Epoch 36/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0037 - accuracy: 0.9990 - val_loss: 0.0662 - val_accuracy: 0.9912
# Epoch 37/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.0605 - val_accuracy: 0.9921
# Epoch 38/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.0628 - val_accuracy: 0.9922
# Epoch 39/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 0.0603 - val_accuracy: 0.9934
# Epoch 40/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.0675 - val_accuracy: 0.9911
# Epoch 41/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0052 - accuracy: 0.9988 - val_loss: 0.0655 - val_accuracy: 0.9923
# Epoch 42/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0046 - accuracy: 0.9988 - val_loss: 0.0690 - val_accuracy: 0.9924
# Epoch 43/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0046 - accuracy: 0.9988 - val_loss: 0.0695 - val_accuracy: 0.9918
# Epoch 44/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0050 - accuracy: 0.9987 - val_loss: 0.0616 - val_accuracy: 0.9916
# Epoch 45/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 0.0659 - val_accuracy: 0.9918
# Epoch 46/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0044 - accuracy: 0.9990 - val_loss: 0.0703 - val_accuracy: 0.9916
# Epoch 47/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0648 - val_accuracy: 0.9927
# Epoch 48/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0054 - accuracy: 0.9987 - val_loss: 0.0747 - val_accuracy: 0.9912
# Epoch 49/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0050 - accuracy: 0.9990 - val_loss: 0.0810 - val_accuracy: 0.9901
# Epoch 50/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0790 - val_accuracy: 0.9914

# %%
model.evaluate(x_test.reshape(-1,28,28,1), t_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0790 - accuracy: 0.9914
# [0.07896257936954498, 0.9914000034332275]

# %%
plt.subplot(121)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss Trends')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.subplot(122)
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy Trends')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
ret_val = model.predict(x_test.reshape(-1,28,28,1))

print(f'ret_val.type : {type(ret_val)}, ret_val.shape : {ret_val.shape}')

predicted_val = np.argmax(ret_val,axis=1)

predicted_comp_list = np.equal(predicted_val, t_test)

index_label_prediction = [ [index, t_test[index], predicted_val[index]] for index, result in enumerate(predicted_comp_list) if result == False ]

print(len(index_label_prediction))
# Out:
# ret_val.type : <class 'numpy.ndarray'>, ret_val.shape : (10000, 10)
# 86

# %%
false_data_index = np.random.randint(len(index_label_prediction))

mnist_index = index_label_prediction[false_data_index][0]
label = index_label_prediction[false_data_index][1]
prediction = index_label_prediction[false_data_index][2]

title_str = f'index = {false_data_index}, label = {label}, pred = {prediction}'

img = x_test[mnist_index].reshape(28,28)

plt.title(title_str)
plt.imshow(img,cmap='gray')
plt.show()
