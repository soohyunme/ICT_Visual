# %%
import tensorflow as tf

from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPool2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist

import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.8.0

# %%
(x_train, t_train), (x_test, t_test) = mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

print('x_train.shape : {0}, x_test.shape : {1}'.format(x_train.shape, x_test.shape))
print('t_train.shape : {0}, t_test.shape : {1}'.format(t_train.shape, t_test.shape))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# x_train.shape : (60000, 28, 28), x_test.shape : (10000, 28, 28)
# t_train.shape : (60000,), t_test.shape : (10000,)

# %%
model = Sequential()

model.add(Conv2D(input_shape=(28,28,1),
                kernel_size=5, filters=32,
                 strides=(1,1), activation='relu', use_bias=True, padding='SAME'))
model.add(MaxPool2D(pool_size=(2,2),padding='SAME'))

model.add(Conv2D(kernel_size=5, filters=64,
                 strides=(1,1), activation='relu', use_bias=True, padding='SAME'))
model.add(MaxPool2D(pool_size=(2,2),padding='SAME'))

model.add(Flatten())

model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        832
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 64)        51264
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 10)                31370
#
# =================================================================
# Total params: 83,466
# Trainable params: 83,466
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_train.reshape(-1,28,28,1), t_train,
                 batch_size=50, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 960/960 [==============================] - 26s 14ms/step - loss: 0.1604 - accuracy: 0.9517 - val_loss: 0.0671 - val_accuracy: 0.9796
# Epoch 2/50
# 960/960 [==============================] - 11s 11ms/step - loss: 0.0506 - accuracy: 0.9839 - val_loss: 0.0477 - val_accuracy: 0.9864
# Epoch 3/50
# 960/960 [==============================] - 9s 10ms/step - loss: 0.0349 - accuracy: 0.9887 - val_loss: 0.0423 - val_accuracy: 0.9884
# Epoch 4/50
# 960/960 [==============================] - 10s 10ms/step - loss: 0.0250 - accuracy: 0.9919 - val_loss: 0.0415 - val_accuracy: 0.9891
# Epoch 5/50
# 960/960 [==============================] - 9s 10ms/step - loss: 0.0196 - accuracy: 0.9939 - val_loss: 0.0401 - val_accuracy: 0.9883
# Epoch 6/50
# 960/960 [==============================] - 10s 10ms/step - loss: 0.0162 - accuracy: 0.9946 - val_loss: 0.0381 - val_accuracy: 0.9888
# Epoch 7/50
# 960/960 [==============================] - 9s 9ms/step - loss: 0.0117 - accuracy: 0.9961 - val_loss: 0.0450 - val_accuracy: 0.9886
# Epoch 8/50
# 960/960 [==============================] - 9s 9ms/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.0419 - val_accuracy: 0.9893
# Epoch 9/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0085 - accuracy: 0.9970 - val_loss: 0.0443 - val_accuracy: 0.9891
# Epoch 10/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.0482 - val_accuracy: 0.9887
# Epoch 11/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0075 - accuracy: 0.9976 - val_loss: 0.0631 - val_accuracy: 0.9862
# Epoch 12/50
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.0529 - val_accuracy: 0.9892
# Epoch 13/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.0547 - val_accuracy: 0.9893
# Epoch 14/50
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.0496 - val_accuracy: 0.9896
# Epoch 15/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.0546 - val_accuracy: 0.9905
# Epoch 16/50
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0042 - accuracy: 0.9984 - val_loss: 0.0752 - val_accuracy: 0.9876
# Epoch 17/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.0606 - val_accuracy: 0.9896
# Epoch 18/50
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.0662 - val_accuracy: 0.9884
# Epoch 19/50
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0716 - val_accuracy: 0.9880
# Epoch 20/50
# 960/960 [==============================] - 8s 9ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.0722 - val_accuracy: 0.9892
# Epoch 21/50
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.0677 - val_accuracy: 0.9897
# Epoch 22/50
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0581 - val_accuracy: 0.9901
# Epoch 23/50
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0025 - accuracy: 0.9991 - val_loss: 0.0651 - val_accuracy: 0.9908
# Epoch 24/50
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.0738 - val_accuracy: 0.9887
# Epoch 25/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0666 - val_accuracy: 0.9901
# Epoch 26/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0041 - accuracy: 0.9988 - val_loss: 0.0672 - val_accuracy: 0.9902
# Epoch 27/50
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.0686 - val_accuracy: 0.9901
# Epoch 28/50
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0707 - val_accuracy: 0.9891
# Epoch 29/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0848 - val_accuracy: 0.9890
# Epoch 30/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0026 - accuracy: 0.9991 - val_loss: 0.0764 - val_accuracy: 0.9893
# Epoch 31/50
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.0712 - val_accuracy: 0.9904
# Epoch 32/50
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0845 - val_accuracy: 0.9898
# Epoch 33/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0993 - val_accuracy: 0.9898
# Epoch 34/50
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0698 - val_accuracy: 0.9902
# Epoch 35/50
# 960/960 [==============================] - 7s 8ms/step - loss: 6.5599e-04 - accuracy: 0.9998 - val_loss: 0.0724 - val_accuracy: 0.9902
# Epoch 36/50
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.0761 - val_accuracy: 0.9900
# Epoch 37/50
# 960/960 [==============================] - 7s 8ms/step - loss: 9.1726e-04 - accuracy: 0.9997 - val_loss: 0.0758 - val_accuracy: 0.9908
# Epoch 38/50
# 960/960 [==============================] - 7s 8ms/step - loss: 3.8375e-04 - accuracy: 0.9999 - val_loss: 0.0665 - val_accuracy: 0.9918
# Epoch 39/50
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.1205 - val_accuracy: 0.9862
# Epoch 40/50
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.0799 - val_accuracy: 0.9900
# Epoch 41/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0851 - val_accuracy: 0.9900
# Epoch 42/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0669 - val_accuracy: 0.9913
# Epoch 43/50
# 960/960 [==============================] - 7s 8ms/step - loss: 3.1260e-04 - accuracy: 0.9998 - val_loss: 0.0847 - val_accuracy: 0.9902
# Epoch 44/50
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0878 - val_accuracy: 0.9912
# Epoch 45/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0046 - accuracy: 0.9988 - val_loss: 0.0915 - val_accuracy: 0.9885
# Epoch 46/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0010 - accuracy: 0.9996 - val_loss: 0.0867 - val_accuracy: 0.9902
# Epoch 47/50
# 960/960 [==============================] - 7s 8ms/step - loss: 7.9368e-04 - accuracy: 0.9997 - val_loss: 0.0992 - val_accuracy: 0.9902
# Epoch 48/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.1131 - val_accuracy: 0.9879
# Epoch 49/50
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.1001 - val_accuracy: 0.9904
# Epoch 50/50
# 960/960 [==============================] - 7s 8ms/step - loss: 5.6917e-04 - accuracy: 0.9999 - val_loss: 0.0881 - val_accuracy: 0.9916

# %%
model.evaluate(x_test.reshape(-1,28,28,1), t_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0673 - accuracy: 0.9911
# [0.06734906136989594, 0.991100013256073]

# %%
plt.figure(figsize=(14,6))
plt.subplot(121)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss Trends')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.subplot(122)
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy Trends')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
ret_val = model.predict(x_test.reshape(-1,28,28,1))

print(f'ret_val.type : {type(ret_val)}, ret_val.shape : {ret_val.shape}')

predicted_val = np.argmax(ret_val,axis=1)

predicted_comp_list = np.equal(predicted_val, t_test)

index_label_prediction = [ [index, t_test[index], predicted_val[index]] for index, result in enumerate(predicted_comp_list) if result == False ]

print(len(index_label_prediction))

# %%
false_data_index = np.random.randint(len(index_label_prediction))

mnist_index = index_label_prediction[false_data_index][0]
label = index_label_prediction[false_data_index][1]
prediction = index_label_prediction[false_data_index][2]

title_str = f'index = {false_data_index}, label = {label}, pred = {prediction}'

img = x_test[mnist_index].reshape(28,28)

plt.title(title_str)
plt.imshow(img,cmap='gray')
plt.show()
