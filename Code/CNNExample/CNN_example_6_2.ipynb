# %%
import tensorflow as tf

from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPool2D, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist

import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.8.0

# %%
(x_train, t_train), (x_test, t_test) = mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

print('x_train.shape : {0}, x_test.shape : {1}'.format(x_train.shape, x_test.shape))
print('t_train.shape : {0}, t_test.shape : {1}'.format(t_train.shape, t_test.shape))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# x_train.shape : (60000, 28, 28), x_test.shape : (10000, 28, 28)
# t_train.shape : (60000,), t_test.shape : (10000,)

# %%
model = Sequential()

# Convolution 1
model.add(Conv2D(input_shape=(28,28,1),
                kernel_size=5, filters=32,
                 strides=(1,1), activation='relu', use_bias=True, padding='SAME'))
model.add(MaxPool2D(pool_size=(2,2),padding='SAME'))

# Convolution 2
model.add(Conv2D(kernel_size=5, filters=32,
                 strides=(1,1), activation='relu', use_bias=True, padding='SAME'))
model.add(MaxPool2D(pool_size=(2,2),padding='SAME'))

model.add(Flatten())

model.add(Dense(128, activation='relu'))

model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        832
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        25632
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 1568)              0
#
#  dense (Dense)               (None, 128)               200832
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 228,586
# Trainable params: 228,586
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_train.reshape(-1,28,28,1), t_train,
                 batch_size=50, epochs=50, validation_data=(x_test.reshape(-1,28,28,1), t_test))
# Out:
# Epoch 1/50
# 1200/1200 [==============================] - 20s 8ms/step - loss: 0.1370 - accuracy: 0.9580 - val_loss: 0.0452 - val_accuracy: 0.9860
# Epoch 2/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0409 - accuracy: 0.9868 - val_loss: 0.0365 - val_accuracy: 0.9876
# Epoch 3/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0285 - accuracy: 0.9909 - val_loss: 0.0304 - val_accuracy: 0.9895
# Epoch 4/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0229 - accuracy: 0.9924 - val_loss: 0.0280 - val_accuracy: 0.9901
# Epoch 5/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0166 - accuracy: 0.9948 - val_loss: 0.0313 - val_accuracy: 0.9904
# Epoch 6/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0123 - accuracy: 0.9961 - val_loss: 0.0293 - val_accuracy: 0.9913
# Epoch 7/50
# 1200/1200 [==============================] - 10s 8ms/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 0.0404 - val_accuracy: 0.9887
# Epoch 8/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.0348 - val_accuracy: 0.9908
# Epoch 9/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0067 - accuracy: 0.9978 - val_loss: 0.0419 - val_accuracy: 0.9899
# Epoch 10/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0072 - accuracy: 0.9975 - val_loss: 0.0303 - val_accuracy: 0.9920
# Epoch 11/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.0362 - val_accuracy: 0.9920
# Epoch 12/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.0392 - val_accuracy: 0.9916
# Epoch 13/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0047 - accuracy: 0.9984 - val_loss: 0.0537 - val_accuracy: 0.9877
# Epoch 14/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0048 - accuracy: 0.9986 - val_loss: 0.0408 - val_accuracy: 0.9903
# Epoch 15/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0535 - val_accuracy: 0.9903
# Epoch 16/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0047 - accuracy: 0.9984 - val_loss: 0.0449 - val_accuracy: 0.9904
# Epoch 17/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.0395 - val_accuracy: 0.9925
# Epoch 18/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.0444 - val_accuracy: 0.9927
# Epoch 19/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.0429 - val_accuracy: 0.9909
# Epoch 20/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0045 - accuracy: 0.9989 - val_loss: 0.0494 - val_accuracy: 0.9901
# Epoch 21/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.0438 - val_accuracy: 0.9903
# Epoch 22/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.0364 - val_accuracy: 0.9929
# Epoch 23/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0045 - accuracy: 0.9987 - val_loss: 0.0552 - val_accuracy: 0.9910
# Epoch 24/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.0357 - val_accuracy: 0.9931
# Epoch 25/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0489 - val_accuracy: 0.9917
# Epoch 26/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.0537 - val_accuracy: 0.9919
# Epoch 27/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0457 - val_accuracy: 0.9931
# Epoch 28/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0559 - val_accuracy: 0.9903
# Epoch 29/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.0502 - val_accuracy: 0.9921
# Epoch 30/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.0621 - val_accuracy: 0.9910
# Epoch 31/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0472 - val_accuracy: 0.9930
# Epoch 32/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 0.0493 - val_accuracy: 0.9916
# Epoch 33/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0559 - val_accuracy: 0.9913
# Epoch 34/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 2.7018e-04 - accuracy: 0.9999 - val_loss: 0.0419 - val_accuracy: 0.9937
# Epoch 35/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 1.0252e-05 - accuracy: 1.0000 - val_loss: 0.0424 - val_accuracy: 0.9939
# Epoch 36/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 2.1235e-06 - accuracy: 1.0000 - val_loss: 0.0425 - val_accuracy: 0.9941
# Epoch 37/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 1.0008e-06 - accuracy: 1.0000 - val_loss: 0.0427 - val_accuracy: 0.9940
# Epoch 38/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 6.6723e-07 - accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 0.9940
# Epoch 39/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 4.2627e-07 - accuracy: 1.0000 - val_loss: 0.0433 - val_accuracy: 0.9939
# Epoch 40/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 2.6395e-07 - accuracy: 1.0000 - val_loss: 0.0438 - val_accuracy: 0.9939
# Epoch 41/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 1.5746e-07 - accuracy: 1.0000 - val_loss: 0.0443 - val_accuracy: 0.9939
# Epoch 42/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 9.3415e-08 - accuracy: 1.0000 - val_loss: 0.0451 - val_accuracy: 0.9939
# Epoch 43/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 5.3463e-08 - accuracy: 1.0000 - val_loss: 0.0461 - val_accuracy: 0.9940
# Epoch 44/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 3.1002e-08 - accuracy: 1.0000 - val_loss: 0.0469 - val_accuracy: 0.9939
# Epoch 45/50
# 1200/1200 [==============================] - 9s 8ms/step - loss: 1.7506e-08 - accuracy: 1.0000 - val_loss: 0.0480 - val_accuracy: 0.9939
# Epoch 46/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 9.8129e-09 - accuracy: 1.0000 - val_loss: 0.0493 - val_accuracy: 0.9939
# Epoch 47/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 5.9148e-09 - accuracy: 1.0000 - val_loss: 0.0504 - val_accuracy: 0.9939
# Epoch 48/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 3.4809e-09 - accuracy: 1.0000 - val_loss: 0.0515 - val_accuracy: 0.9940
# Epoch 49/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 2.1279e-09 - accuracy: 1.0000 - val_loss: 0.0527 - val_accuracy: 0.9937
# Epoch 50/50
# 1200/1200 [==============================] - 9s 7ms/step - loss: 1.3212e-09 - accuracy: 1.0000 - val_loss: 0.0538 - val_accuracy: 0.9938

# %%
model.evaluate(x_test.reshape(-1,28,28,1), t_test)
# Out:
# 313/313 [==============================] - 2s 4ms/step - loss: 0.0538 - accuracy: 0.9938
# [0.05383225157856941, 0.9937999844551086]

# %%
plt.subplot(121)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss Trends')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.subplot(122)
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy Trends')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
ret_val = model.predict(x_test.reshape(-1,28,28,1))

print(f'ret_val.type : {type(ret_val)}, ret_val.shape : {ret_val.shape}')

predicted_val = np.argmax(ret_val,axis=1)

predicted_comp_list = np.equal(predicted_val, t_test)

index_label_prediction = [ [index, t_test[index], predicted_val[index]] for index, result in enumerate(predicted_comp_list) if result == False ]

print(len(index_label_prediction))
# Out:
# ret_val.type : <class 'numpy.ndarray'>, ret_val.shape : (10000, 10)
# 62

# %%
false_data_index = np.random.randint(len(index_label_prediction))

mnist_index = index_label_prediction[false_data_index][0]
label = index_label_prediction[false_data_index][1]
prediction = index_label_prediction[false_data_index][2]

title_str = f'index = {false_data_index}, label = {label}, pred = {prediction}'

img = x_test[mnist_index].reshape(28,28)

plt.title(title_str)
plt.imshow(img,cmap='gray')
plt.show()
