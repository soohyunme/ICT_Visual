# %%
import tensorflow as tf

from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPool2D, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist

import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.8.0

# %%
(x_train, t_train), (x_test, t_test) = mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

print('x_train.shape : {0}, x_test.shape : {1}'.format(x_train.shape, x_test.shape))
print('t_train.shape : {0}, t_test.shape : {1}'.format(t_train.shape, t_test.shape))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# x_train.shape : (60000, 28, 28), x_test.shape : (10000, 28, 28)
# t_train.shape : (60000,), t_test.shape : (10000,)

# %%
model = Sequential()

model.add(Conv2D(input_shape=(28,28,1),
                kernel_size=5, filters=32,
                 strides=(1,1), activation='relu', use_bias=True, padding='SAME'))
model.add(MaxPool2D(pool_size=(2,2),padding='SAME'))
model.add(Dropout(0.25))

model.add(Conv2D(kernel_size=5, filters=64,
                 strides=(1,1), activation='relu', use_bias=True, padding='SAME'))
model.add(MaxPool2D(pool_size=(2,2),padding='SAME'))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        832
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  dropout (Dropout)           (None, 14, 14, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 64)        51264
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 7, 7, 64)          0
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 10)                31370
#
# =================================================================
# Total params: 83,466
# Trainable params: 83,466
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_train.reshape(-1,28,28,1), t_train,
                 batch_size=50, epochs=50, validation_data=(x_test.reshape(-1,28,28,1), t_test))
# Out:
# Epoch 1/50
# 1200/1200 [==============================] - 16s 4ms/step - loss: 0.1747 - accuracy: 0.9466 - val_loss: 0.0497 - val_accuracy: 0.9841
# Epoch 2/50
# 1200/1200 [==============================] - 5s 4ms/step - loss: 0.0576 - accuracy: 0.9819 - val_loss: 0.0321 - val_accuracy: 0.9893
# Epoch 3/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0433 - accuracy: 0.9864 - val_loss: 0.0348 - val_accuracy: 0.9883
# Epoch 4/50
# 1200/1200 [==============================] - 5s 4ms/step - loss: 0.0362 - accuracy: 0.9889 - val_loss: 0.0325 - val_accuracy: 0.9892
# Epoch 5/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0311 - accuracy: 0.9897 - val_loss: 0.0276 - val_accuracy: 0.9909
# Epoch 6/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0257 - accuracy: 0.9917 - val_loss: 0.0262 - val_accuracy: 0.9913
# Epoch 7/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0244 - accuracy: 0.9922 - val_loss: 0.0200 - val_accuracy: 0.9927
# Epoch 8/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0201 - accuracy: 0.9932 - val_loss: 0.0219 - val_accuracy: 0.9924
# Epoch 9/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0195 - accuracy: 0.9937 - val_loss: 0.0232 - val_accuracy: 0.9920
# Epoch 10/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0165 - accuracy: 0.9946 - val_loss: 0.0223 - val_accuracy: 0.9937
# Epoch 11/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0146 - accuracy: 0.9949 - val_loss: 0.0250 - val_accuracy: 0.9924
# Epoch 12/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0160 - accuracy: 0.9948 - val_loss: 0.0231 - val_accuracy: 0.9926
# Epoch 13/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0138 - accuracy: 0.9954 - val_loss: 0.0259 - val_accuracy: 0.9930
# Epoch 14/50
# 1200/1200 [==============================] - 5s 4ms/step - loss: 0.0139 - accuracy: 0.9951 - val_loss: 0.0229 - val_accuracy: 0.9928
# Epoch 15/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0126 - accuracy: 0.9955 - val_loss: 0.0214 - val_accuracy: 0.9934
# Epoch 16/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0134 - accuracy: 0.9959 - val_loss: 0.0243 - val_accuracy: 0.9934
# Epoch 17/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0112 - accuracy: 0.9962 - val_loss: 0.0260 - val_accuracy: 0.9938
# Epoch 18/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0106 - accuracy: 0.9964 - val_loss: 0.0317 - val_accuracy: 0.9921
# Epoch 19/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0104 - accuracy: 0.9966 - val_loss: 0.0253 - val_accuracy: 0.9928
# Epoch 20/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0100 - accuracy: 0.9965 - val_loss: 0.0236 - val_accuracy: 0.9938
# Epoch 21/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0097 - accuracy: 0.9967 - val_loss: 0.0275 - val_accuracy: 0.9934
# Epoch 22/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 0.0293 - val_accuracy: 0.9926
# Epoch 23/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0095 - accuracy: 0.9968 - val_loss: 0.0250 - val_accuracy: 0.9940
# Epoch 24/50
# 1200/1200 [==============================] - 5s 4ms/step - loss: 0.0089 - accuracy: 0.9971 - val_loss: 0.0276 - val_accuracy: 0.9941
# Epoch 25/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0088 - accuracy: 0.9967 - val_loss: 0.0270 - val_accuracy: 0.9927
# Epoch 26/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.0290 - val_accuracy: 0.9937
# Epoch 27/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0075 - accuracy: 0.9974 - val_loss: 0.0310 - val_accuracy: 0.9935
# Epoch 28/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.0273 - val_accuracy: 0.9940
# Epoch 29/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.0280 - val_accuracy: 0.9934
# Epoch 30/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0077 - accuracy: 0.9976 - val_loss: 0.0285 - val_accuracy: 0.9938
# Epoch 31/50
# 1200/1200 [==============================] - 5s 4ms/step - loss: 0.0086 - accuracy: 0.9972 - val_loss: 0.0315 - val_accuracy: 0.9930
# Epoch 32/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0078 - accuracy: 0.9972 - val_loss: 0.0286 - val_accuracy: 0.9943
# Epoch 33/50
# 1200/1200 [==============================] - 5s 4ms/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.0307 - val_accuracy: 0.9934
# Epoch 34/50
# 1200/1200 [==============================] - 5s 4ms/step - loss: 0.0079 - accuracy: 0.9974 - val_loss: 0.0290 - val_accuracy: 0.9937
# Epoch 35/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 0.0294 - val_accuracy: 0.9941
# Epoch 36/50
# 1200/1200 [==============================] - 5s 4ms/step - loss: 0.0074 - accuracy: 0.9977 - val_loss: 0.0314 - val_accuracy: 0.9935
# Epoch 37/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0084 - accuracy: 0.9973 - val_loss: 0.0338 - val_accuracy: 0.9931
# Epoch 38/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0067 - accuracy: 0.9978 - val_loss: 0.0259 - val_accuracy: 0.9944
# Epoch 39/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0090 - accuracy: 0.9973 - val_loss: 0.0336 - val_accuracy: 0.9917
# Epoch 40/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0070 - accuracy: 0.9975 - val_loss: 0.0339 - val_accuracy: 0.9934
# Epoch 41/50
# 1200/1200 [==============================] - 5s 4ms/step - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.0337 - val_accuracy: 0.9940
# Epoch 42/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0067 - accuracy: 0.9979 - val_loss: 0.0352 - val_accuracy: 0.9929
# Epoch 43/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.0350 - val_accuracy: 0.9927
# Epoch 44/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0062 - accuracy: 0.9981 - val_loss: 0.0365 - val_accuracy: 0.9933
# Epoch 45/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0062 - accuracy: 0.9983 - val_loss: 0.0349 - val_accuracy: 0.9934
# Epoch 46/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0058 - accuracy: 0.9982 - val_loss: 0.0413 - val_accuracy: 0.9927
# Epoch 47/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0071 - accuracy: 0.9979 - val_loss: 0.0407 - val_accuracy: 0.9926
# Epoch 48/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.0360 - val_accuracy: 0.9932
# Epoch 49/50
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.0355 - val_accuracy: 0.9937
# Epoch 50/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.0391 - val_accuracy: 0.9930

# %%
model.evaluate(x_test.reshape(-1,28,28,1), t_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0391 - accuracy: 0.9930
# [0.039057787507772446, 0.9929999709129333]

# %%
plt.subplot(121)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss Trends')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.subplot(122)
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy Trends')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
ret_val = model.predict(x_test.reshape(-1,28,28,1))

print(f'ret_val.type : {type(ret_val)}, ret_val.shape : {ret_val.shape}')

predicted_val = np.argmax(ret_val,axis=1)

predicted_comp_list = np.equal(predicted_val, t_test)

index_label_prediction = [ [index, t_test[index], predicted_val[index]] for index, result in enumerate(predicted_comp_list) if result == False ]

print(len(index_label_prediction))
# Out:
# ret_val.type : <class 'numpy.ndarray'>, ret_val.shape : (10000, 10)
# 70

# %%
false_data_index = np.random.randint(len(index_label_prediction))

mnist_index = index_label_prediction[false_data_index][0]
label = index_label_prediction[false_data_index][1]
prediction = index_label_prediction[false_data_index][2]

title_str = f'index = {false_data_index}, label = {label}, pred = {prediction}'

img = x_test[mnist_index].reshape(28,28)

plt.title(title_str)
plt.imshow(img,cmap='gray')
plt.show()
