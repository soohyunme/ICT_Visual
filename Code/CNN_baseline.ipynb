# %%
import tensorflow as tf

from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPool2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist

import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.8.0

# %%
(x_train, t_train), (x_test, t_test) = mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

print('x_train.shape : {0}, x_test.shape : {1}'.format(x_train.shape, x_test.shape))
print('t_train.shape : {0}, t_test.shape : {1}'.format(t_train.shape, t_test.shape))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# x_train.shape : (60000, 28, 28), x_test.shape : (10000, 28, 28)
# t_train.shape : (60000,), t_test.shape : (10000,)

# %%
model = Sequential()

model.add(Conv2D(input_shape=(28,28,1),
                kernel_size=3, filters=32,
                 strides=(1,1), activation='relu', use_bias=True, padding='SAME'))

model.add(MaxPool2D(pool_size=(2,2),padding='SAME'))

model.add(Flatten())

model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 10)                62730
#
# =================================================================
# Total params: 63,050
# Trainable params: 63,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_train.reshape(-1,28,28,1), t_train,
                 batch_size=50, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 960/960 [==============================] - 26s 27ms/step - loss: 0.3056 - accuracy: 0.9123 - val_loss: 0.1440 - val_accuracy: 0.9610
# Epoch 2/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.1119 - accuracy: 0.9682 - val_loss: 0.0974 - val_accuracy: 0.9704
# Epoch 3/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.0783 - accuracy: 0.9772 - val_loss: 0.0795 - val_accuracy: 0.9776
# Epoch 4/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.0627 - accuracy: 0.9823 - val_loss: 0.0708 - val_accuracy: 0.9798
# Epoch 5/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.0538 - accuracy: 0.9836 - val_loss: 0.0701 - val_accuracy: 0.9794
# Epoch 6/50
# 960/960 [==============================] - 23s 24ms/step - loss: 0.0459 - accuracy: 0.9857 - val_loss: 0.0766 - val_accuracy: 0.9778
# Epoch 7/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.0403 - accuracy: 0.9881 - val_loss: 0.0684 - val_accuracy: 0.9803
# Epoch 8/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.0356 - accuracy: 0.9893 - val_loss: 0.0701 - val_accuracy: 0.9796
# Epoch 9/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.0313 - accuracy: 0.9908 - val_loss: 0.0684 - val_accuracy: 0.9812
# Epoch 10/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.0270 - accuracy: 0.9918 - val_loss: 0.0715 - val_accuracy: 0.9795
# Epoch 11/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.0237 - accuracy: 0.9934 - val_loss: 0.0716 - val_accuracy: 0.9801
# Epoch 12/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.0211 - accuracy: 0.9942 - val_loss: 0.0705 - val_accuracy: 0.9808
# Epoch 13/50
# 960/960 [==============================] - 23s 24ms/step - loss: 0.0183 - accuracy: 0.9950 - val_loss: 0.0759 - val_accuracy: 0.9799
# Epoch 14/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.0158 - accuracy: 0.9957 - val_loss: 0.0749 - val_accuracy: 0.9810
# Epoch 15/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.0141 - accuracy: 0.9960 - val_loss: 0.0775 - val_accuracy: 0.9813
# Epoch 16/50
# 960/960 [==============================] - 24s 24ms/step - loss: 0.0115 - accuracy: 0.9968 - val_loss: 0.0785 - val_accuracy: 0.9792
# Epoch 17/50
# 960/960 [==============================] - 23s 24ms/step - loss: 0.0107 - accuracy: 0.9974 - val_loss: 0.0811 - val_accuracy: 0.9811
# Epoch 18/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.0087 - accuracy: 0.9980 - val_loss: 0.0887 - val_accuracy: 0.9797
# Epoch 19/50
# 960/960 [==============================] - 25s 26ms/step - loss: 0.0077 - accuracy: 0.9979 - val_loss: 0.0850 - val_accuracy: 0.9806
# Epoch 20/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.0078 - accuracy: 0.9979 - val_loss: 0.0848 - val_accuracy: 0.9795
# Epoch 21/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.0059 - accuracy: 0.9986 - val_loss: 0.0857 - val_accuracy: 0.9810
# Epoch 22/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.0055 - accuracy: 0.9987 - val_loss: 0.0935 - val_accuracy: 0.9784
# Epoch 23/50
# 960/960 [==============================] - 25s 26ms/step - loss: 0.0047 - accuracy: 0.9990 - val_loss: 0.0936 - val_accuracy: 0.9814
# Epoch 24/50
# 960/960 [==============================] - 25s 26ms/step - loss: 0.0035 - accuracy: 0.9995 - val_loss: 0.0944 - val_accuracy: 0.9801
# Epoch 25/50
# 960/960 [==============================] - 25s 26ms/step - loss: 0.0047 - accuracy: 0.9988 - val_loss: 0.0992 - val_accuracy: 0.9799
# Epoch 26/50
# 960/960 [==============================] - 25s 26ms/step - loss: 0.0043 - accuracy: 0.9989 - val_loss: 0.1010 - val_accuracy: 0.9795
# Epoch 27/50
# 960/960 [==============================] - 25s 26ms/step - loss: 0.0025 - accuracy: 0.9996 - val_loss: 0.1051 - val_accuracy: 0.9800
# Epoch 28/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.0037 - accuracy: 0.9990 - val_loss: 0.1111 - val_accuracy: 0.9796
# Epoch 29/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.1021 - val_accuracy: 0.9803
# Epoch 30/50
# 960/960 [==============================] - 25s 26ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.1041 - val_accuracy: 0.9794
# Epoch 31/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.1060 - val_accuracy: 0.9814
# Epoch 32/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.1094 - val_accuracy: 0.9798
# Epoch 33/50
# 960/960 [==============================] - 25s 26ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.1075 - val_accuracy: 0.9799
# Epoch 34/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.1121 - val_accuracy: 0.9792
# Epoch 35/50
# 960/960 [==============================] - 25s 26ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.1053 - val_accuracy: 0.9811
# Epoch 36/50
# 960/960 [==============================] - 24s 25ms/step - loss: 7.9024e-04 - accuracy: 0.9999 - val_loss: 0.1144 - val_accuracy: 0.9804
# Epoch 37/50
# 960/960 [==============================] - 23s 24ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.1186 - val_accuracy: 0.9805
# Epoch 38/50
# 960/960 [==============================] - 25s 26ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.1081 - val_accuracy: 0.9804
# Epoch 39/50
# 960/960 [==============================] - 24s 25ms/step - loss: 3.9946e-04 - accuracy: 1.0000 - val_loss: 0.1095 - val_accuracy: 0.9815
# Epoch 40/50
# 960/960 [==============================] - 23s 24ms/step - loss: 2.3796e-04 - accuracy: 1.0000 - val_loss: 0.1113 - val_accuracy: 0.9821
# Epoch 41/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.1359 - val_accuracy: 0.9777
# Epoch 42/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.1245 - val_accuracy: 0.9793
# Epoch 43/50
# 960/960 [==============================] - 24s 25ms/step - loss: 6.1801e-04 - accuracy: 0.9999 - val_loss: 0.1131 - val_accuracy: 0.9810
# Epoch 44/50
# 960/960 [==============================] - 24s 25ms/step - loss: 2.1771e-04 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 0.9809
# Epoch 45/50
# 960/960 [==============================] - 24s 25ms/step - loss: 1.4390e-04 - accuracy: 1.0000 - val_loss: 0.1173 - val_accuracy: 0.9808
# Epoch 46/50
# 960/960 [==============================] - 23s 24ms/step - loss: 1.2236e-04 - accuracy: 1.0000 - val_loss: 0.1219 - val_accuracy: 0.9817
# Epoch 47/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.1372 - val_accuracy: 0.9806
# Epoch 48/50
# 960/960 [==============================] - 24s 25ms/step - loss: 0.0010 - accuracy: 0.9999 - val_loss: 0.1261 - val_accuracy: 0.9797
# Epoch 49/50
# 960/960 [==============================] - 24s 25ms/step - loss: 2.2994e-04 - accuracy: 1.0000 - val_loss: 0.1179 - val_accuracy: 0.9810
# Epoch 50/50
# 960/960 [==============================] - 24s 25ms/step - loss: 1.2710e-04 - accuracy: 1.0000 - val_loss: 0.1207 - val_accuracy: 0.9818

# %%
model.evaluate(x_test.reshape(-1,28,28,1), t_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1057 - accuracy: 0.9820
# [0.10568636655807495, 0.9819999933242798]
