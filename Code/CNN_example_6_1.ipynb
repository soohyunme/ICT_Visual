# %%
import tensorflow as tf

from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPool2D, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist

import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.8.0

# %%
(x_train, t_train), (x_test, t_test) = mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

print('x_train.shape : {0}, x_test.shape : {1}'.format(x_train.shape, x_test.shape))
print('t_train.shape : {0}, t_test.shape : {1}'.format(t_train.shape, t_test.shape))
# Out:
# x_train.shape : (60000, 28, 28), x_test.shape : (10000, 28, 28)
# t_train.shape : (60000,), t_test.shape : (10000,)

# %%
model = Sequential()

model.add(Conv2D(input_shape=(28,28,1),
                kernel_size=5, filters=32,
                 strides=(1,1), activation='relu', use_bias=True, padding='SAME'))
model.add(MaxPool2D(pool_size=(2,2),padding='SAME'))

model.add(Flatten())

model.add(Dense(128, activation='relu'))

model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)        832
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 6272)              0
#
#  dense_2 (Dense)             (None, 128)               802944
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 805,066
# Trainable params: 805,066
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_train.reshape(-1,28,28,1), t_train,
                 batch_size=50, epochs=50, validation_data=(x_test.reshape(-1,28,28,1), t_test))
# Out:
# Epoch 1/50
# 1200/1200 [==============================] - 17s 6ms/step - loss: 0.1409 - accuracy: 0.9582 - val_loss: 0.0523 - val_accuracy: 0.9829
# Epoch 2/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0478 - accuracy: 0.9850 - val_loss: 0.0478 - val_accuracy: 0.9835
# Epoch 3/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0319 - accuracy: 0.9896 - val_loss: 0.0370 - val_accuracy: 0.9863
# Epoch 4/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0222 - accuracy: 0.9929 - val_loss: 0.0402 - val_accuracy: 0.9864
# Epoch 5/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0164 - accuracy: 0.9946 - val_loss: 0.0341 - val_accuracy: 0.9896
# Epoch 6/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0114 - accuracy: 0.9963 - val_loss: 0.0361 - val_accuracy: 0.9884
# Epoch 7/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0089 - accuracy: 0.9970 - val_loss: 0.0418 - val_accuracy: 0.9879
# Epoch 8/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0079 - accuracy: 0.9972 - val_loss: 0.0448 - val_accuracy: 0.9886
# Epoch 9/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 0.0475 - val_accuracy: 0.9883
# Epoch 10/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0047 - accuracy: 0.9983 - val_loss: 0.0494 - val_accuracy: 0.9888
# Epoch 11/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0056 - accuracy: 0.9980 - val_loss: 0.0445 - val_accuracy: 0.9897
# Epoch 12/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0036 - accuracy: 0.9988 - val_loss: 0.0515 - val_accuracy: 0.9887
# Epoch 13/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0037 - accuracy: 0.9987 - val_loss: 0.0545 - val_accuracy: 0.9874
# Epoch 14/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0034 - accuracy: 0.9988 - val_loss: 0.0642 - val_accuracy: 0.9875
# Epoch 15/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0035 - accuracy: 0.9988 - val_loss: 0.0588 - val_accuracy: 0.9878
# Epoch 16/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.0605 - val_accuracy: 0.9885
# Epoch 17/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0034 - accuracy: 0.9988 - val_loss: 0.0578 - val_accuracy: 0.9889
# Epoch 18/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.0687 - val_accuracy: 0.9874
# Epoch 19/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.0543 - val_accuracy: 0.9885
# Epoch 20/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0658 - val_accuracy: 0.9875
# Epoch 21/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0630 - val_accuracy: 0.9897
# Epoch 22/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0685 - val_accuracy: 0.9876
# Epoch 23/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0034 - accuracy: 0.9988 - val_loss: 0.0620 - val_accuracy: 0.9888
# Epoch 24/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0588 - val_accuracy: 0.9897
# Epoch 25/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0669 - val_accuracy: 0.9891
# Epoch 26/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0702 - val_accuracy: 0.9885
# Epoch 27/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0807 - val_accuracy: 0.9873
# Epoch 28/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0721 - val_accuracy: 0.9890
# Epoch 29/50
# 1200/1200 [==============================] - 8s 7ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0736 - val_accuracy: 0.9885
# Epoch 30/50
# 1200/1200 [==============================] - 11s 9ms/step - loss: 9.6123e-05 - accuracy: 1.0000 - val_loss: 0.0798 - val_accuracy: 0.9883
# Epoch 31/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0724 - val_accuracy: 0.9901
# Epoch 32/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0861 - val_accuracy: 0.9893
# Epoch 33/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 5.5809e-04 - accuracy: 0.9998 - val_loss: 0.0959 - val_accuracy: 0.9868
# Epoch 34/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 7.8511e-04 - accuracy: 0.9998 - val_loss: 0.0845 - val_accuracy: 0.9891
# Epoch 35/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.1161 - val_accuracy: 0.9861
# Epoch 36/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.1039 - val_accuracy: 0.9874
# Epoch 37/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1042 - val_accuracy: 0.9879
# Epoch 38/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.0938 - val_accuracy: 0.9886
# Epoch 39/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.1039 - val_accuracy: 0.9880
# Epoch 40/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.1028 - val_accuracy: 0.9885
# Epoch 41/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.1059 - val_accuracy: 0.9880
# Epoch 42/50
# 1200/1200 [==============================] - 8s 7ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.0927 - val_accuracy: 0.9888
# Epoch 43/50
# 1200/1200 [==============================] - 8s 6ms/step - loss: 3.6048e-04 - accuracy: 0.9998 - val_loss: 0.0997 - val_accuracy: 0.9892
# Epoch 44/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 7.6182e-05 - accuracy: 1.0000 - val_loss: 0.0941 - val_accuracy: 0.9895
# Epoch 45/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 4.2768e-06 - accuracy: 1.0000 - val_loss: 0.0934 - val_accuracy: 0.9896
# Epoch 46/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 1.4494e-06 - accuracy: 1.0000 - val_loss: 0.0942 - val_accuracy: 0.9898
# Epoch 47/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 6.3716e-07 - accuracy: 1.0000 - val_loss: 0.0945 - val_accuracy: 0.9898
# Epoch 48/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 4.3720e-07 - accuracy: 1.0000 - val_loss: 0.0947 - val_accuracy: 0.9899
# Epoch 49/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 2.9394e-07 - accuracy: 1.0000 - val_loss: 0.0955 - val_accuracy: 0.9897
# Epoch 50/50
# 1200/1200 [==============================] - 7s 6ms/step - loss: 1.9302e-07 - accuracy: 1.0000 - val_loss: 0.0962 - val_accuracy: 0.9898

# %%
model.evaluate(x_test.reshape(-1,28,28,1), t_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0962 - accuracy: 0.9898
# [0.09617842733860016, 0.989799976348877]

# %%
plt.subplot(121)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss Trends')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.subplot(122)
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy Trends')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
ret_val = model.predict(x_test.reshape(-1,28,28,1))

print(f'ret_val.type : {type(ret_val)}, ret_val.shape : {ret_val.shape}')

predicted_val = np.argmax(ret_val,axis=1)

predicted_comp_list = np.equal(predicted_val, t_test)

index_label_prediction = [ [index, t_test[index], predicted_val[index]] for index, result in enumerate(predicted_comp_list) if result == False ]

print(len(index_label_prediction))
# Out:
# ret_val.type : <class 'numpy.ndarray'>, ret_val.shape : (10000, 10)
# 102

# %%
false_data_index = np.random.randint(len(index_label_prediction))

mnist_index = index_label_prediction[false_data_index][0]
label = index_label_prediction[false_data_index][1]
prediction = index_label_prediction[false_data_index][2]

title_str = f'index = {false_data_index}, label = {label}, pred = {prediction}'

img = x_test[mnist_index].reshape(28,28)

plt.title(title_str)
plt.imshow(img,cmap='gray')
plt.show()
